# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/JHSERIES2/blob/main/17_Series_Tiempo_Cap15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Curso Introductorio Series de Tiempo por Julio Hurtado Márquez**
# ## **Text: Time Series Forecasting in Python - MARCO PEIXEIRO**
# # **Parte 3. Predicciones a gran escala con aprendizaje profundo**

# %% [markdown]
# ## **Introducción**
# + Los modelos estadísticos tienen sus limitaciones, especialmente cuando un conjunto de datos es grande y tiene muchas características y relaciones no lineales.
# + En tales casos, el aprendizaje profundo es la herramienta perfecta para la previsión de series temporales.
# + En esta parte del libro, trabajaremos con un conjunto de datos masivo y aplicaremos diferentes arquitecturas de aprendizaje profundo, como **la memoria a corto plazo larga (LSTM), una red neuronal convolucional (CNN) y una red neuronal profunda autorregresiva, para predecir el futuro de nuestra serie**.
# + Nuevamente, concluiremos esta parte con un proyecto final para poner a prueba sus habilidades.
# + El aprendizaje profundo es un subconjunto del aprendizaje automático y, por lo tanto, es posible utilizar algoritmos de aprendizaje automático más tradicionales para la previsión de series temporales, como **árboles potenciados por gradiente**.
# + Para mantener esta sección razonable, no cubriremos esas técnicas específicamente, aunque se requiere la creación de ventanas de datos para pronosticar series temporales con aprendizaje automático, y aplicaremos este concepto numerosas veces.

# %% [markdown]
# # **15. Recordando el pasado con LSTM**
#
# ## **Esta parte de Este capítulo cubre**
# + Examen de la arquitectura de la memoria a corto y largo plazo (LSTM)
# + Implementación de una LSTM con Keras
#
# ## **Una arquitectura más avanzada llamada memoria a corto plazo larga (LSTM)**
# + En el último capítulo, construimos nuestros primeros modelos en aprendizaje profundo, implementando modelos de redes neuronales tanto lineales como profundas.
# + En el caso de nuestro conjunto de datos, vimos que ambos modelos superaron las líneas de base que construimos en el capítulo 13, siendo la red neuronal profunda el mejor modelo para tareas de un solo paso, de varios pasos y de múltiples salidas.
# + Ahora exploraremos una arquitectura más avanzada llamada memoria a corto plazo larga (LSTM), que es un caso particular de una red neuronal recurrente (RNN).
# + Este tipo de red neuronal se utiliza para procesar secuencias de datos, donde el orden importa.
# + Una aplicación común de *RNN y LSTM* es en el procesamiento del lenguaje natural.
# + Las palabras en una oración tienen un orden, y cambiar ese orden puede cambiar por completo el significado de una oración.
# + Por lo tanto, a menudo encontramos esta arquitectura detrás de algoritmos de clasificación y generación de texto.
# + Otra situación en la que el orden de los datos importa es en las series temporales.
# + Sabemos que las series temporales son secuencias de datos igualmente espaciadas en el tiempo y que su orden no se puede cambiar.
# + El punto de datos observado a las 9 a. m. debe aparecer antes del punto de datos a las 10 a. m. y después del punto de datos a las 8 a. m.
# + Por lo tanto, tiene sentido aplicar la arquitectura LSTM para pronosticar series temporales.
# + En este capítulo, primero exploraremos la arquitectura general de una red neuronal recurrente y luego profundizaremos en la arquitectura LSTM y examinaremos sus características únicas y su funcionamiento interno.
# + Luego implementaremos una LSTM utilizando Keras para producir modelos de un solo paso, de varios pasos y de múltiples salidas.
# + Finalmente, compararemos el rendimiento de LSTM con todos los modelos que hemos creado, desde las líneas base hasta las redes neuronales profundas.

# %% [markdown]
# # **15.1. Exploración de la red neuronal recurrente (RNN)**
# + Una red neuronal recurrente (RNN) es una arquitectura de aprendizaje profundo especialmente adaptada al procesamiento de secuencias de datos.
# + Denota un conjunto de redes que comparten una arquitectura similar:
# *La memoria a corto plazo larga (LSTM) y la unidad recurrente controlada (GRU) son subtipos de RNN*.
# + En este capítulo, nos centraremos únicamente en la arquitectura LSTM.
# + Para comprender el funcionamiento interno de una RNN, comenzaremos con la figura 15.1, que muestra una ilustración compacta de una RNN.
# + Al igual que en una red neuronal profunda (DNN), tenemos una entrada, denotada como $x_t$, y una salida, denotada como $y_t$.
# + Aquí $x_t$ es un elemento de una secuencia.
# + Cuando se envía a la RNN, calcula un estado oculto, denotado como $h_t$.
# + Este estado oculto actúa como memoria.
# + Se calcula para cada elemento de la secuencia y se devuelve a la RNN como entrada.
# + De esta manera, la red utiliza de manera efectiva la información pasada calculada para elementos anteriores de la secuencia para informar la salida para el siguiente elemento de la secuencia.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Red neuronal recurrente**
# + Una red neuronal recurrente (RNN) está especialmente adaptada al procesamiento de secuencias de datos.
# + Utiliza un estado oculto que se retroalimenta a la red para que pueda utilizar información pasada como entrada al procesar el siguiente elemento de una secuencia.
# + De esta manera, replica el concepto de memoria.
# + Sin embargo, las RNN sufren de memoria a corto plazo, lo que significa que la información de un elemento anterior en la secuencia dejará de tener impacto más adelante en la secuencia.
# + **La figura 15.2 muestra una ilustración ampliada de una red neuronal recurrente. Se puede ver cómo el estado oculto se calcula primero en t = 0 y luego se actualiza y se transmite a medida que se procesa cada elemento de la secuencia. Así es como la red neuronal recurrente replica de manera efectiva el concepto de memoria y utiliza información pasada para producir un nuevo resultado.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  ### **las RNN básicas que hemos examinado tienen un inconveniente**
# + Sin embargo, las RNN básicas que hemos examinado tienen un inconveniente: sufren de memoria a corto plazo debido al gradiente evanescente.
# + El gradiente es simplemente la función que le dice a la red cómo cambiar los pesos.
# + Si el cambio en el gradiente es grande, los pesos cambian en una gran magnitud.
# + Por otro lado, si el cambio en el gradiente es pequeño, los pesos no cambian significativamente.
# + El problema del *gradiente evanescente* se refiere a lo que sucede cuando el cambio en el gradiente se vuelve muy pequeño, a veces cercano a 0.
# + Esto a su vez significa que los pesos de la red no se actualizan y la red deja de aprender.
# + En la práctica, esto significa que la RNN olvida la información pasada que está muy lejos en la secuencia.
# + Por lo tanto, sufre de memoria a corto plazo. Por ejemplo, si una RNN está procesando 24 horas de datos horarios, los puntos en las horas 9, 10 y 11 podrían afectar el resultado en la hora 12, pero cualquier punto anterior a la hora 9 podría no contribuir en absoluto al aprendizaje de la red, porque el gradiente se vuelve muy pequeño para esos primeros puntos de datos.
# + Por lo tanto, debemos encontrar una manera de retener la importancia de la información pasada en nuestra red.
# + Esto nos lleva a la arquitectura de memoria a corto y largo plazo (LSTM), que utiliza el estado de la celda como una forma adicional de mantener la información pasada en la memoria durante mucho tiempo.

# %% [markdown]
# # **15.2 Examinando la arquitectura LSTM**
# + La arquitectura de memoria de corto plazo a largo plazo (LSTM) agrega un estado de celda a la arquitectura RNN para evitar el problema del gradiente evanescente, donde la información pasada deja de afectar el aprendizaje de la red.
# + Esto permite que la red mantenga la información pasada en la memoria por más tiempo.
# + La arquitectura LSTM se muestra en la figura 15.3, y puede ver que es más compleja que la arquitectura RNN básica.
# + Notará la adición del estado de celda, denotado como $C$.
# + Este estado de celda es lo que permite que la red mantenga la información pasada en la red por más tiempo, resolviendo así el problema del gradiente evanescente.
# + Tenga en cuenta que esto es exclusivo de la arquitectura LSTM.
# + Todavía tenemos un elemento de una secuencia que se está procesando, que se muestra como $x_t$, y también se calcula un estado oculto, denotado como $h_t$.
# + En este caso, tanto el estado de la celda $C_t$ como el $h_t$ oculto se pasan al siguiente elemento de la secuencia, lo que garantiza que la información pasada se use como entrada para el siguiente elemento
# en la secuencia que se está procesando.
# + También notarás la presencia de tres puertas: la puerta de olvido, la puerta de entrada y la puerta de salida. Cada una tiene su función específica en el LSTM, así que vamos a explorar cada una en detalle.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Acerca de Memoria a corto plazo a largo plazo - LSTM**
# + La memoria a corto plazo a largo plazo (LSTM, por sus siglas en inglés) es una arquitectura de aprendizaje profundo que es un subtipo de RNN. La LSTM aborda el problema de la memoria a corto plazo agregando el estado de la celda.
# + Esto permite que la información pasada fluya a través de la red durante un período de tiempo más largo, lo que significa que la red aún transporta información de los primeros valores de la secuencia.
# + La LSTM se compone de tres puertas:
#   + La puerta de olvido determina qué información de los pasos anteriores sigue siendo relevante.
#   + La puerta de entrada determina qué información del paso actual es relevante.
#   + La puerta de salida determina qué información se transmite al siguiente elemento de la secuencia o, como resultado, a la capa de salida.

# %% [markdown]
# # **15.2.1 La puerta de olvido - forget  gate**
# + La puerta de olvido es la primera puerta en una celda LSTM.
# + Su función es determinar qué información, tanto de los valores pasados ​​como del valor actual de la secuencia, se debe olvidar o conservar en la red.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# + Observando la figura 15.4, podemos ver cómo fluyen las diferentes entradas a través de la compuerta de olvido.
# + Primero, el estado oculto pasado $h_{t–1}$ y el valor actual de una secuencia $x_{t}$ se introducen en la compuerta de olvido.
# + Recordemos que el estado oculto pasado lleva información de valores pasados.
# + Luego, $h_{t–1}$ y $x_{t}$ se combinan y duplican.
# + Una copia va directamente a la compuerta de entrada, que estudiaremos en la siguiente sección.
# + La otra copia se envía a través de una función de activación *sigmoide*, que se expresa como la ecuación 15.1 y se muestra en la figura 15.5.
# + La función *sigmoide* determina qué información se debe conservar o se debe olvidar.
# + Luego, esa salida se combina con el estado de celda anterior $C_{t–1}$ mediante la multiplicación puntual.
# + Esto da como resultado un estado de celda actualizado que llamamos $C'_{t–1}$.
# + Una vez hecho esto, se envían dos cosas a la compuerta de entrada: un estado de celda actualizado y una copia de la combinación del estado oculto pasado y el elemento actual de la secuencia.
# + Función sigmoide $f(x) =(1 + exp(-x))^{-1} , -10<x<10$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definimos la función corregida
def f(x):
    return (1 + np.exp(-x)) ** (-1)

# Definimos el rango de x
x = np.linspace(-10, 10, 400)
y = f(x)

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'r', label=r'$f(x) = (1 + e^{-x})^{-1}$')
plt.title('Gráfico de la función $f(x) = (1 + e^{-x})^{-1}$')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, which='both')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# + **Figura 15.5 La función sigmoide genera valores entre 0 y 1. En el contexto de la compuerta de olvido, si la salida de la función sigmoide es cercana a 0, la salida es información que se olvida. Si la salida es cercana a 1, es información que se debe conservar.**
# + Una vez hecho esto, se envían dos cosas a la puerta de entrada: un estado de celda actualizado y una copia de la combinación del estado oculto anterior y el elemento actual de la secuencia.

# %% [markdown]
# # **15.2.2 La puerta de entrada**
# + Una vez que la información ha pasado por la puerta de olvido, pasa a la puerta de entrada.
# + Este es el paso en el que la red determina qué información es relevante del elemento actual de la secuencia.
# + El estado de la celda se actualiza nuevamente aquí, lo que da como resultado el estado final de la celda.
# + Nuevamente, acerquemos la vista a la puerta de entrada utilizando la figura 15.6.
# + La combinación del estado oculto anterior y el elemento actual de una secuencia $[h_{t–1} + x_t]$ que proviene de la puerta de olvido se introduce en la puerta de entrada y se duplica nuevamente.
# + Una copia sale por la puerta de entrada hacia la puerta de salida, que exploraremos en la siguiente sección.
# + Otra copia se envía a través de la función de activación sigmoidea para determinar si la información se conservará o se olvidará.
# + *Otra copia se envía a través de la función tangente hiperbólica (tanh), que se muestra en la figura 15.7.*

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definimos la función tangente hiperbólica
def f(x):
    return np.tanh(x)

# Definimos el rango de x
x = np.linspace(-10, 10, 400)
y = f(x)

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, y, 'r', label=r'f(x) = tanh(x)')
plt.title('Gráfico de la función f(x) = tanh(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.axhline(0, color='black', linewidth=0.5)
plt.axvline(0, color='black', linewidth=0.5)
plt.grid(True, which='both')
plt.legend()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# + **Figura 15.7 La función tangente hiperbólica (tanh) genera valores entre –1 y 1. En el contexto del LSTM, esto sirve como una forma de regular la red, asegurándose de que los valores no sean muy grandes y asegurando que el cálculo siga siendo eficiente.**

# %% [markdown]
# + Las salidas de las funciones sigmoidea y tanh se combinan mediante la multiplicación puntual, y el resultado se combina con el estado de celda actualizado que proviene de la compuerta de olvido $C'_{t–1}$ mediante la suma puntual.
# + Esta operación genera el estado de celda final $C_t$.
# + Por lo tanto, es en la compuerta de entrada donde agregamos información del elemento actual en la secuencia a la memoria larga de la red.
# + Este estado de celda recientemente actualizado se envía luego a la compuerta de salida.

# %% [markdown]
# # **15.2.3. La puerta de salida**
# + La información ha pasado de la puerta de olvido a la puerta de entrada y ahora llega a la puerta de salida.
# + Es en esta puerta donde la información anterior contenida en la memoria de la red, representada por el estado de la celda $C_t$, se utiliza finalmente para procesar el elemento actual de la secuencia.
# + Aquí es también donde la red envía un resultado a la capa de salida o calcula nueva información para enviarla al procesamiento del siguiente elemento de la secuencia.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# + En la figura 15.8, el estado oculto pasado y el elemento actual de una secuencia se envían a través de la función *sigmoide*.
# + En paralelo, el estado de la celda pasa por la función *tanh*.
# + Los valores resultantes de las funciones *tanh* y *sigmoide* se combinan luego mediante la multiplicación puntual, generando un estado oculto actualizado $h_t$.
# + Este es el paso en el que la información pasada, representada por el estado de la celda $C_t$, se utiliza para procesar la información del elemento actual de la secuencia.
# + El estado oculto actual se envía luego por la compuerta de salida. Este se enviará a la capa de salida de la red o a la siguiente neurona LSTM que trata el siguiente elemento de la secuencia.
# + Lo mismo se aplica para el estado de la celda $C_t$.
# + En resumen, la compuerta de olvido determina qué información del pasado se conserva o se descarta.
# + La compuerta de entrada determina qué información del paso actual se conserva para actualizar la memoria de la red o se descarta.
# + Finalmente, la compuerta de salida utiliza la información del pasado almacenada en la memoria de la red para procesar el elemento actual de una secuencia.
# + Después de examinar el funcionamiento interno de la arquitectura LSTM, ahora podemos implementarla para nuestro conjunto de datos de tráfico interestatal.

# %% [markdown]
# # **15.3 Implementación de la arquitectura LSTM**
# + Ahora implementaremos la arquitectura LSTM para el conjunto de datos de tráfico interestatal con el que hemos estado trabajando desde el capítulo 12.
# + Recuerde que el objetivo principal de nuestro escenario es el volumen de tráfico.
# + Para el modelo de múltiples salidas, los objetivos son el volumen de tráfico y la temperatura.
# + Implementaremos LSTM como un modelo de un solo paso, un modelo de múltiples pasos y un modelo de múltiples salidas.
# + El modelo de un solo paso predecirá el volumen de tráfico solo para el siguiente paso de tiempo, el modelo de múltiples pasos predecirá el volumen de tráfico para las siguientes 24 horas y el modelo de múltiples salidas predecirá la temperatura y el volumen de tráfico para el siguiente paso de tiempo.
# + Asegúrese de tener la clase DataWindow y la función `compile_and_fit` (de los capítulos 13 y 14) en su cuaderno o secuencia de comandos de Python, ya que usaremos estos fragmentos de código para crear ventanas de datos y entrenar el modelo LSTM.
# + El otro requisito previo es leer el conjunto de entrenamiento, el conjunto de validación y el conjunto de prueba, así que hagámoslo ahora mismo:

# %% [markdown]
# # **Paso 1. Las librerias de necesarias**
# + El primer paso natural es importar las bibliotecas que serán necesarias para completar el proyecto.
# + Luego podemos cargar los datos y almacenarlos en un DataFrame para usarlos durante todo el proyecto.
# + Por lo tanto, importaremos las siguientes bibliotecas y especificaremos la función mágica %matplotlib inline para mostrar los gráficos en el cuaderno:

# %%
#### **Paso 1. Las librerias de necesarias**
import datetime

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.keras import Model, Sequential

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import MeanAbsoluteError

from tensorflow.keras.layers import Dense, Conv1D, LSTM, Lambda, Reshape, RNN, LSTMCell

# %%
# Ignorar advertencias innecesarias
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Paso 2. Importando los datos**
# + Una vez importadas las bibliotecas, podemos leer los datos y almacenarlos en un DataFrame.
# + Como se mencionó, este conjunto de datos es una versión abreviada y depurada del conjunto de datos original disponible en el repositorio de aprendizaje automático de UCI.
# + En este caso, el conjunto de datos comienza el 29 de septiembre de 2016 a las 5 p. m. y finaliza el 30 de septiembre de 2018 a las 11 p. m.
# + Si utilizamos df.shape, podemos ver que tenemos un total de seis características y 17551 filas.
# + Las características incluyen la fecha y la hora, la temperatura, la cantidad de lluvia y nieve, la cobertura de nubes y el volumen de tráfico. La Tabla 12.1 describe cada columna con más detalle.
#
# + **Tabla 12.1 Variables en el conjunto de datos de volumen de tráfico interestatal metropolitano**
#
#
# |Característica |Descripción|
# |:--|:--:|
# |date_time| Fecha y hora de los datos, registrados en la zona horaria CST. El formato es AAAA-MM-DD HH:MM:SS.
# |temp |Temperatura promedio registrada en la hora, expresada en Kelvin.
# |rain_1h| Cantidad de lluvia que cayó en la hora, expresada en milímetros.
# |snow_1h| Cantidad de nieve que cayó en la hora, expresada en milímetros.
# |clouds_all| Porcentaje de nubosidad durante la hora.
# |Traffic_volume| Volumen de tráfico informado en dirección oeste por la I-94 durante la hora.

# %%
## **Paso 2. Importando los datos**

df = pd.read_csv('/content/metro_interstate_traffic_volume_preprocessed.csv')
df.head(10) # Muestra las primeras cinco filas de datos.
# Out:
#              date_time    temp  rain_1h  snow_1h  clouds_all  traffic_volume
# 0  2016-09-29 17:00:00  291.75      0.0        0           0          5551.0
# 1  2016-09-29 18:00:00  290.36      0.0        0           0          4132.0
# 2  2016-09-29 19:00:00  287.86      0.0        0           0          3435.0
# 3  2016-09-29 20:00:00  285.91      0.0        0           0          2765.0
# 4  2016-09-29 21:00:00  284.31      0.0        0           0          2443.0
# 5  2016-09-29 22:00:00  284.37      0.0        0           0          2076.0
# 6  2016-09-29 23:00:00  284.53      0.0        0           0          1116.0
# 7  2016-09-30 00:00:00  284.26      0.0        0           0           660.0
# 8  2016-09-30 01:00:00  283.99      0.0        0           0           384.0
# 9  2016-09-30 02:00:00  283.17      0.0        0           0           281.0

# %%
df.shape
# Out:
# (17551, 6)

# %%
# Muestra el tamaño de mis datos.
print(len(df))
# Out:
# 17551

# %%
# Muestra las ultimas 10 filas de datos.
df.tail(10)
# Out:
#                  date_time    temp  rain_1h  snow_1h  clouds_all  \
# 17541  2018-09-30 14:00:00  283.48     0.00        0          90
# 17542  2018-09-30 15:00:00  283.84     0.00        0          75
# 17543  2018-09-30 16:00:00  284.38     0.00        0          75
# 17544  2018-09-30 17:00:00  284.79     0.00        0          75
# 17545  2018-09-30 18:00:00  284.20     0.25        0          75
# 17546  2018-09-30 19:00:00  283.45     0.00        0          75
# 17547  2018-09-30 20:00:00  282.76     0.00        0          90
# 17548  2018-09-30 21:00:00  282.73     0.00        0          90
# 17549  2018-09-30 22:00:00  282.09     0.00        0          90
# 17550  2018-09-30 23:00:00  282.12     0.00        0          90
#
#        traffic_volume
# 17541          4380.0
# 17542          4302.0
# 17543          4283.0
# 17544          4132.0
# 17545          3947.0
# 17546          3543.0
# 17547          2781.0
# 17548          2159.0
# 17549          1450.0
# 17550           954.0

# %% [markdown]
# # **Paso 3. Dibuje nuestra variable objetivo de Pronostico**
# + Ahora, visualicemos la evolución del volumen de tráfico a lo largo del tiempo.
# + Dado que nuestro conjunto de datos es muy grande, con más de 17000 registros, representaremos gráficamente solo los primeros 400 puntos de datos, lo que equivale aproximadamente a dos semanas de datos.
# + El resultado se muestra en la figura 12.4.

# %%
fig, ax = plt.subplots()

ax.plot(df['traffic_volume'])
ax.set_xlabel('Time')
ax.set_ylabel('Traffic volume')

plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# + En la figura 12.4 se puede apreciar una estacionalidad diaria clara, ya que el volumen de tráfico es menor al principio y al final de cada día.
# + También se puede observar un volumen de tráfico menor durante los fines de semana.
# + En cuanto a la tendencia, es probable que dos semanas de datos no sean suficientes para sacar una conclusión razonable, pero parece que el volumen no aumenta ni disminuye con el tiempo en la figura.
# + También podemos representar gráficamente la temperatura por hora, ya que será un objetivo para nuestros modelos de múltiples salidas.
# + Aquí, esperamos ver estacionalidad anual y diaria.
# + La estacionalidad anual debería deberse a las estaciones del año, mientras que la estacionalidad diaria se deberá al hecho de que las temperaturas tienden a ser más bajas por la noche y más altas durante el día.

# %% [markdown]
# # **Paso 4. Si existe algun patron estacional construya un grafico donde se aprecie el patron**
# + Primero, visualicemos la temperatura horaria en todo el conjunto de datos para ver si podemos identificar alguna estacionalidad anual. El resultado se muestra en la figura 12.5.

# %%
fig, ax = plt.subplots()

ax.plot(df['temp'])
ax.set_xlabel('Time')
ax.set_ylabel('Temperature (K)')

plt.xticks([2239, 10999], [2017, 2018])

fig.autofmt_xdate()
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **Temperatura horaria (en Kelvin) del 29 de septiembre de 2016 al 30 de septiembre de 2018. Aunque hay ruido, podemos ver un patrón estacional anual.**

# %% [markdown]
# ### **Acerca de la descomposición de la serie**
# + En la figura 12.5 se puede observar un patrón estacional anual en la temperatura horaria, ya que las temperaturas son más bajas a finales y principios de año (invierno en Minnesota) y más altas a mediados de año (verano).
# + Por lo tanto, como se esperaba, la temperatura tiene estacionalidad anual.
# + Ahora, verifiquemos si podemos observar estacionalidad diaria en la temperatura. El resultado se muestra en la figura 12.6.

# %%
fig, ax = plt.subplots()

ax.plot(df['temp'])
ax.set_xlabel('Time')
ax.set_ylabel('Temperature (K)')

plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **Figura 12.6 Temperatura horaria (en Kelvin) a partir del 29 de septiembre de 2016 a las 5 p.m. CST. Aunque es un poco ruidosa, podemos ver que las temperaturas son efectivamente más bajas al principio y al final de cada día y alcanzan su punto máximo durante el mediodía, lo que sugiere una estacionalidad diaria.**
# + En la figura 12.6 se puede observar que la temperatura es más baja al principio y al final de cada día y alcanza su punto máximo hacia la mitad de cada día. Esto sugiere una estacionalidad diaria, tal como observamos para el volumen de tráfico en la figura 12.4.

# %% [markdown]
# # **Paso 5. Ingeniería de características y división de datos**
# ## **Ingeniería de características y división de datos**
# + Una vez que hayamos terminado de explorar los datos, pasaremos a la ingeniería de características y la división de datos.
# + En esta sección, estudiaremos cada característica y crearemos otras nuevas que ayudarán a nuestros modelos a pronosticar el volumen de tráfico y la temperatura por hora.
# + Por último, dividiremos los datos y guardaremos cada conjunto como un archivo CSV para su uso posterior.
# + Una excelente manera de estudiar las características de un conjunto de datos es utilizar el método describe de pandas.
# + Este método devuelve la cantidad de registros para cada característica, lo que nos permite identificar rápidamente los valores faltantes, la media, la desviación estándar, los cuartiles y los valores máximos y mínimos de cada característica.

# %% [markdown]
# ## **a. El método de transposición coloca cada entidad en su propia fila**
#
# + A partir de la salida, notará que rain_1h es mayoritariamente 0 en todo el conjunto de datos, ya que su tercer cuartil aún está en 0.
# + Dado que al menos el 75 % de los valores de rain_1h son 0, es poco probable que sea un predictor sólido del volumen de tráfico. Por lo tanto, esta característica se eliminará.
# + Si observa snow_1h, notará que esta variable está en 0 en todo el conjunto de datos. Esto es fácilmente observable, ya que sus valores mínimo y máximo son ambos 0.
# + Por lo tanto, esto no predice la variación en el volumen de tráfico a lo largo del tiempo. Esta característica también se eliminará del conjunto de datos.

# %%
df.describe().transpose() # El método de transposición coloca cada entidad en su propia fila.
# Out:
#                   count         mean          std     min      25%      50%  \
# temp            17551.0   281.416203    12.688262  243.39   272.22   282.41
# rain_1h         17551.0     0.025523     0.259794    0.00     0.00     0.00
# snow_1h         17551.0     0.000000     0.000000    0.00     0.00     0.00
# clouds_all      17551.0    42.034129    39.065960    0.00     1.00    40.00
# traffic_volume  17551.0  3321.484588  1969.223949  113.00  1298.00  3518.00
#
#                     75%      max
# temp             291.89   310.07
# rain_1h            0.00    10.60
# snow_1h            0.00     0.00
# clouds_all        90.00   100.00
# traffic_volume  4943.00  7280.00

# %% [markdown]
# ### **b. Eliminando las variables inocuas**

# %%
### **b. Eliminando las variables inocuas**
cols_to_drop = ['rain_1h', 'snow_1h']
df = df.drop(cols_to_drop, axis=1)
df.shape
# Out:
# (17551, 4)

# %% [markdown]
# ## **c. codificando la característica date_time**
# + Ahora llegamos al interesante problema de codificar el tiempo como una característica utilizable para nuestros modelos de aprendizaje profundo.
# + En este momento, la característica date_time no es utilizable por nuestros modelos, ya que es una cadena de fecha y hora.
# + Por lo tanto, la convertiremos en un valor numérico.
# + Una forma sencilla de hacerlo es expresar la fecha como una cantidad de segundos. Esto se logra mediante el uso del método timestamp de la biblioteca datetime.

# %%
# **c. codificando la característica date_time**
timestamp_s = pd.to_datetime(df['date_time']).map(datetime.datetime.timestamp)

# %%
fft = tf.signal.rfft(df['traffic_volume'])
f_per_dataset = np.arange(0, len(fft))

n_sample_h = len(df['traffic_volume'])
hours_per_week = 24 * 7
weeks_per_dataset = n_sample_h / hours_per_week

f_per_week = f_per_dataset / weeks_per_dataset

plt.step(f_per_week, np.abs(fft))
plt.xscale('log')
plt.xticks([1, 7], ['1/week', '1/day'])
plt.xlabel('Frequency')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### **d. Acerca del paso anterior**
# + Lamentablemente, no hemos terminado, ya que esto simplemente expresa cada fecha en segundos, como se muestra en la figura 12.7.
# + Esto nos lleva a perder la naturaleza cíclica del tiempo, porque la cantidad de segundos simplemente aumenta linealmente con el tiempo.
# + Por lo tanto, debemos aplicar una transformación para recuperar el comportamiento cíclico del tiempo.
#
# #### **e. Recuperando la propiedad ciclica**
# + Una forma sencilla de hacerlo es aplicar una transformación seno.
# + Sabemos que la función seno es cíclica, acotada entre -1 y 1. Esto nos ayudará a recuperar parte de la propiedad cíclica del tiempo.
# + **La marca de tiempo está en segundos, por lo que debemos calcular la cantidad de segundos de un día antes de aplicar la transformación del seno.**
# + **Aplicación de la transformación seno. Observe que utilizamos radianes en la función seno.**

# %%
# **e. Recuperando la propiedad ciclica**
day = 24 * 60 * 60

df['day_sin'] = (np.sin(timestamp_s * (2*np.pi/day))).values
df['day_cos'] = (np.cos(timestamp_s * (2*np.pi/day))).values

# %%
df = df.drop(['date_time'], axis=1) # Eliminar la columna date_time

df.head()
# Out:
#      temp  clouds_all  traffic_volume   day_sin       day_cos
# 0  291.75           0          5551.0 -0.965926 -2.588190e-01
# 1  290.36           0          4132.0 -1.000000 -4.048636e-12
# 2  287.86           0          3435.0 -0.965926  2.588190e-01
# 3  285.91           0          2765.0 -0.866025  5.000000e-01
# 4  284.31           0          2443.0 -0.707107  7.071068e-01

# %% [markdown]
# ### **f. Transformacion seno - coseno**
# + Con una única transformación de seno, recuperamos parte de la propiedad cíclica que se perdió al convertir a segundos.
# + Sin embargo, en este punto, las 12 p. m. equivalen a las 12 a. m. y las 5 p. m. equivalen a las 5 a. m.
# + Esto no es deseable, ya que queremos distinguir entre la mañana y la tarde.
# + Por lo tanto, aplicaremos una transformación de coseno. Sabemos que el coseno está desfasado con la función seno.
# + Esto nos permite distinguir entre las 5 a. m. y las 5 p. m., expresando la naturaleza cíclica del tiempo en un día. En este punto, podemos eliminar la columna date_time del DataFrame.

# %%
# **f. Transformacion seno - coseno**
df.sample(50).plot.scatter('day_sin','day_cos').set_aspect('equal');
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# ## **Acerca de la Transformacion seno - coseno**
# + En la figura 12.8, notará que los puntos forman un círculo, como un reloj.
# + Por lo tanto, hemos expresado con éxito cada marca de tiempo como un punto en el reloj, lo que significa que ahora tenemos valores numéricos que conservan la naturaleza cíclica del tiempo en un día, y esto se puede usar en nuestros modelos de aprendizaje profundo.
# + Esto será útil ya que observamos la estacionalidad diaria tanto de la temperatura como del volumen de tráfico.

# %% [markdown]
# ### **Paso 7. Conjunto de entrenamiento, validación y prueba**
#
# + *Una vez completada la ingeniería de características, ahora podemos dividir nuestros conjuntos de datos de entrenamiento, validación y prueba*.
# + El conjunto de entrenamiento es la muestra de datos que se usa para ajustar el modelo.
# + El conjunto de validación es un poco como un conjunto de prueba que el modelo puede revisar para ajustar sus hiperparámetros y mejorar su rendimiento durante el entrenamiento del modelo.
# + El conjunto de prueba está completamente separado del procedimiento de entrenamiento del modelo y se usa para una evaluación imparcial del rendimiento del modelo.
# + **Aquí usaremos una división simple de 70:20:10 para los conjuntos de entrenamiento, validación y prueba. Si bien el 10% de los datos parece una porción pequeña para el conjunto de prueba, recuerde que tenemos más de 17000 registros, lo que significa que evaluaremos el modelo en más de 1000 puntos de datos, lo cual es más que suficiente.**

# %%
n = len(df)

# Split 70:20:10 (train:validation:test)
train_df = df[0:int(n*0.7)]
val_df = df[int(n*0.7):int(n*0.9)]
test_df = df[int(n*0.9):]

train_df.shape, val_df.shape, test_df.shape

print(f'Longitud del conjunto de Datos es = {len(df)}')
print(f'Longitud del conjunto de Entrenamiento es = {len(train_df)}')
print(f'Longitud del conjunto de Validación es = {len(val_df)}')
print(f'Longitud del conjunto de prueba es = {len(test_df)}')
# Out:
# Longitud del conjunto de Datos es = 17551
# Longitud del conjunto de Entrenamiento es = 12285
# Longitud del conjunto de Validación es = 3510
# Longitud del conjunto de prueba es = 1756

# %%
df.head() # recordemos cuales son nuestras variables
# Out:
#      temp  clouds_all  traffic_volume   day_sin       day_cos
# 0  291.75           0          5551.0 -0.965926 -2.588190e-01
# 1  290.36           0          4132.0 -1.000000 -4.048636e-12
# 2  287.86           0          3435.0 -0.965926  2.588190e-01
# 3  285.91           0          2765.0 -0.866025  5.000000e-01
# 4  284.31           0          2443.0 -0.707107  7.071068e-01

# %%
df.tail() # recordemos cuales son nuestras variables
# Out:
#          temp  clouds_all  traffic_volume   day_sin   day_cos
# 17546  283.45          75          3543.0 -0.965926  0.258819
# 17547  282.76          90          2781.0 -0.866025  0.500000
# 17548  282.73          90          2159.0 -0.707107  0.707107
# 17549  282.09          90          1450.0 -0.500000  0.866025
# 17550  282.12          90           954.0 -0.258819  0.965926

# %% [markdown]
# ### **Paso 8. debemos escalarlos para que todos los valores estén entre 0 y 1**
# + Antes de guardar los datos, debemos escalarlos para que todos los valores estén entre 0 y 1.
# + Esto reduce el tiempo necesario para entrenar los modelos de aprendizaje profundo y mejora su rendimiento.
# + Usaremos `MinMaxScaler` de `sklearn` para escalar nuestros datos.
# + Tenga en cuenta que ajustaremos el escalador al conjunto de entrenamiento para evitar fugas de datos.
# + De esa manera, simulamos el hecho de que solo tenemos los datos de entrenamiento disponibles cuando usamos el modelo y el modelo no conoce información futura. La evaluación del modelo permanece imparcial.

# %%
## **8. Escalando los datos**
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
scaler.fit(train_df)

train_df[train_df.columns] = scaler.transform(train_df[train_df.columns])
val_df[val_df.columns] = scaler.transform(val_df[val_df.columns])
test_df[test_df.columns] = scaler.transform(test_df[test_df.columns])

# %% [markdown]
# ### **Paso 9. Parámetros escalados del modelo**
# + Vale la pena mencionar por qué los datos se escalan y no se normalizan.
# + Escalado y normalización pueden ser términos confusos para los científicos de datos, ya que a menudo se usan indistintamente.
# + En resumen, **escalar los datos afecta solo su escala y no su distribución**.
# + Por lo tanto, simplemente fuerza los valores dentro de un rango determinado.
# + En nuestro caso, forzamos los valores a estar entre 0 y 1.
# + **Normalizar los datos, por otro lado, afecta su distribución y su escala**.
# + Por lo tanto, normalizar los datos los obligaría a tener una distribución normal o una distribución gaussiana.
# + El rango original también cambiaría y trazar la frecuencia de cada valor generaría una curva de campana clásica.
# + Normalizar los datos solo es útil cuando los modelos que usamos requieren que los datos sean normales.
# + Por ejemplo, el análisis discriminante lineal (LDA) se deriva del supuesto de una distribución normal, por lo que es mejor normalizar los datos antes de usar LDA.
# + Sin embargo, en el caso del aprendizaje profundo, no se hacen suposiciones, por lo que la normalización no es necesaria.

# %%
train_df.describe().transpose()
# Out:
#                   count      mean       std  min       25%       50%  \
# temp            12285.0  0.555681  0.196527  0.0  0.424800  0.557913
# clouds_all      12285.0  0.431034  0.393716  0.0  0.010000  0.400000
# traffic_volume  12285.0  0.445735  0.273635  0.0  0.165899  0.473141
# day_sin         12285.0  0.500084  0.353568  0.0  0.146447  0.500000
# day_cos         12285.0  0.500084  0.353568  0.0  0.146447  0.500000
#
#                      75%  max
# temp            0.715072  1.0
# clouds_all      0.900000  1.0
# traffic_volume  0.671271  1.0
# day_sin         0.853553  1.0
# day_cos         0.853553  1.0

# %% [markdown]
# ### **Paso 10. Guardar los Datos como Archivo SCV**
# + Finalmente, guardaremos cada conjunto como un archivo CSV para usarlo en los siguientes capítulos.

# %%
train_df.to_csv('train.csv')
val_df.to_csv('val.csv')
test_df.to_csv('test.csv')

# %% [markdown]
# ### **Paso 11. Explorando cómo se entrenan los modelos de aprendizaje profundo para la previsión de series temporales**

# %%
fig, ax = plt.subplots()

for n in range(0,17,2):
    start = 24*n
    stop = 24*(n+1)
    ax.plot(train_df.traffic_volume[start:stop], marker='s', color='blue', label='input')
    ax.plot(train_df.traffic_volume[stop:2*stop], marker='x', color='red', label='label')
ax.set_xlabel('Time')
ax.set_ylabel('Traffic volume')

plt.xticks(np.arange(7, 400, 24), ['Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.xlim(0, 400)

fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# ### **Paso 12. Implementando la clase DataWindow**
#
# + A continuación, definiremos una función para representar gráficamente los datos de entrada, las predicciones y los valores reales (listado 13.2).
# + Dado que trabajaremos con muchas ventanas de tiempo, mostraremos solo el gráfico de tres ventanas de tiempo, pero este parámetro se puede cambiar fácilmente.
# + Además, la etiqueta predeterminada será el volumen de tráfico, pero podemos cambiarla especificando cualquier columna que elijamos.
# + Nuevamente, esta función debe incluirse en la clase DataWindow.

# %%
class DataWindow():
    def __init__(self, input_width, label_width, shift,
                 train_df=train_df, val_df=val_df, test_df=test_df,
                 label_columns=None):

        self.train_df = train_df
        self.val_df = val_df
        self.test_df = test_df

        self.label_columns = label_columns
        if label_columns is not None:
            self.label_columns_indices = {name: i for i, name in enumerate(label_columns)}
        self.column_indices = {name: i for i, name in enumerate(train_df.columns)}

        self.input_width = input_width
        self.label_width = label_width
        self.shift = shift

        self.total_window_size = input_width + shift

        self.input_slice = slice(0, input_width)
        self.input_indices = np.arange(self.total_window_size)[self.input_slice]

        self.label_start = self.total_window_size - self.label_width
        self.labels_slice = slice(self.label_start, None)
        self.label_indices = np.arange(self.total_window_size)[self.labels_slice]

    def split_to_inputs_labels(self, features):
        inputs = features[:, self.input_slice, :]
        labels = features[:, self.labels_slice, :]
        if self.label_columns is not None:
            labels = tf.stack(
                [labels[:,:,self.column_indices[name]] for name in self.label_columns],
                axis=-1
            )
        inputs.set_shape([None, self.input_width, None])
        labels.set_shape([None, self.label_width, None])

        return inputs, labels

    def plot(self, model=None, plot_col='traffic_volume', max_subplots=3):
        inputs, labels = self.sample_batch

        plt.figure(figsize=(12, 8))
        plot_col_index = self.column_indices[plot_col]
        max_n = min(max_subplots, len(inputs))

        for n in range(max_n):
            plt.subplot(3, 1, n+1)
            plt.ylabel(f'{plot_col} [scaled]')
            plt.plot(self.input_indices, inputs[n, :, plot_col_index],
                     label='Inputs', marker='.', zorder=-10)
# Grafique las entradas. Aparecerán como una línea azul continua con puntos.

            if self.label_columns:
              label_col_index = self.label_columns_indices.get(plot_col, None)
            else:
              label_col_index = plot_col_index

            if label_col_index is None:
              continue

            plt.scatter(self.label_indices, labels[n, :, label_col_index],
                        edgecolors='k', marker='s', label='Labels', c='green', s=64)
            # Grafique las etiquetas o los valores reales. Aparecerán como cuadrados verdes.
            if model is not None:
              predictions = model(inputs)
              plt.scatter(self.label_indices, predictions[n, :, label_col_index],
                          marker='X', edgecolors='k', label='Predictions',
                          c='red', s=64)
# Grafica las predicciones. Aparecerán como cruces rojas.
            if n == 0:
              plt.legend()

        plt.xlabel('Time (h)')
# Pase los datos. Esto corresponde a nuestro conjunto de entrenamiento, conjunto de validación o conjunto de prueba.
    def make_dataset(self, data):
        data = np.array(data, dtype=np.float32)
        ds = tf.keras.preprocessing.timeseries_dataset_from_array(
            data=data,
            targets=None,
            sequence_length=self.total_window_size,
            sequence_stride=1,
            shuffle=True,
            batch_size=32
        )
  # Los objetivos se establecen en Ninguno, ya que son manejados por la función split_to_input_labels.
        ds = ds.map(self.split_to_inputs_labels)
        return ds

    @property
    def train(self):
        return self.make_dataset(self.train_df)

    @property
    def val(self):
        return self.make_dataset(self.val_df)

    @property
    def test(self):
        return self.make_dataset(self.test_df)

    @property
    def sample_batch(self):
        result = getattr(self, '_sample_batch', None)
        if result is None:
            result = next(iter(self.train))
            self._sample_batch = result
        return result

# %% [markdown]
# ### **Clase DataWindow creada**
#
# + Por ahora, la clase DataWindow puede parecer un poco abstracta, pero pronto la usaremos para aplicar modelos de referencia.
# + Usaremos esta clase en todos los capítulos de esta parte del libro dedicada al aprendizaje profundo, por lo que poco a poco dominarás este código y apreciarás lo fácil que es probar diferentes arquitecturas de aprendizaje profundo.

# %% [markdown]
# ### **Paso 13. Modelo de línea base de un solo paso**
# + Para fines de representación gráfica, también definiremos una ventana más amplia para poder visualizar muchas predicciones de nuestro modelo.
# + De lo contrario, solo podríamos visualizar un punto de datos de entrada y una predicción de salida, lo que no es muy interesante.

# %%
# **Paso 13. Modelo de línea base de un solo paso**
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume'])
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %% [markdown]
# + En esta situación, la predicción más simple que podemos hacer es el último valor observado.
# + Básicamente, la predicción es simplemente el punto de datos de entrada.
# + Esto se implementa mediante la clase Baseline.
# + Como puede ver en la siguiente lista, la clase Baseline también se puede utilizar para un modelo de múltiples salidas.
# + Por ahora, nos centraremos únicamente en un modelo de un solo paso.

# %%
class Baseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index

    def call(self, inputs):
        if self.label_index is None:
            return inputs

        elif isinstance(self.label_index, list):
            tensors = []
            for index in self.label_index:
                result = inputs[:, :, index]
                result = result[:, :, tf.newaxis]
                tensors.append(result)
            return tf.concat(tensors, axis=-1)

        result = inputs[:, :, self.label_index]
        return result[:,:,tf.newaxis]

# %% [markdown]
# ### **Paso 14. Una vez definida la clase, podemos inicializar el modelo y compilarlo para generar predicciones**.
# + Para ello, buscaremos el índice de nuestra columna de destino, Traffic_volume, y lo pasaremos a Baseline.
# + Tenga en cuenta que **TensorFlow** requiere que proporcionemos una función de pérdida y una métrica de evaluación.
# + En este caso, y a lo largo de los capítulos de aprendizaje profundo, **utilizaremos el error cuadrático medio (MSE) como función de pérdida**: penaliza los errores grandes y, por lo general, produce modelos bien ajustados.
# + **Para la métrica de evaluación, utilizaremos el error absoluto medio (MAE) por su facilidad de interpretación.**

# %%
## **a. Definimos la función de perdida y la métrica**
# Genere un diccionario con el nombre y el índice de cada columna en el conjunto de entrenamiento.
column_indices = {name: i for i, name in enumerate(train_df.columns)}

# Pase el índice de la columna de destino en la clase Baseline.
baseline_last = Baseline(label_index=column_indices['traffic_volume'])

# Compilar el modelo para generar las predicciones.
baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

# %% [markdown]
# ### **Paso 15. Ahora evaluaremos el rendimiento de nuestra línea base tanto en el conjunto de validación como en el de prueba.**
# + Los modelos creados con TensorFlow cuentan con el método de evaluación, que nos permite comparar las predicciones con los valores reales y calcular la métrica de error.

# %%
# Cree un diccionario para almacenar el MAE de un modelo en el conjunto de validación.
val_performance = {}

# Cree un diccionario para almacenar el MAE de un modelo en el conjunto de prueba.
performance = {}

#Almacene el MAE de baseline en el conjunto de validación.
val_performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.val)
# Almacene el MAE de la línea base en el conjunto de prueba.
performance['Baseline - Last'] = baseline_last.evaluate(single_step_window.test, verbose=0)
# Out:
# 110/110 [==============================] - 1s 3ms/step - loss: 0.0133 - mean_absolute_error: 0.0831

# %% [markdown]
# ### **Paso 16. Podemos visualizar las predicciones utilizando el método plot de la clase DataWindow.**
# + Genial, hemos creado con éxito una línea base que predice el último valor conocido y lo hemos evaluado. Podemos visualizar las predicciones utilizando el método plot de la clase DataWindow.
# + Recuerda utilizar wide_window para ver más de dos puntos de datos.

# %%
wide_window.plot(baseline_last)

plt.savefig('figures', dpi=300)

# %% [markdown]
# ### **Acerca del paso 16**
# + **Figura 13.9 Predicciones de nuestro modelo de referencia de un solo paso en tres secuencias del lote de muestra. La predicción en cada paso de tiempo es el último valor conocido, lo que significa que nuestra referencia funciona como se esperaba.**
# + En la figura 13.9, las etiquetas son cuadrados y las predicciones son cruces.
# + Las cruces en cada paso de tiempo son simplemente el último valor conocido, lo que significa que tenemos una línea base que funciona como se esperaba.
# + Su gráfico puede diferir del de la figura 13.9, ya que el lote de muestra almacenado en caché cambia cada vez que se inicializa una ventana de datos.

# %% [markdown]
# ### **Paso 17. Opcionalmente podemos imprimir el MAE de nuestra línea base en el conjunto de prueba.**
# + Esto devuelve un MAE de 0,081.
# + Los modelos más complejos deberían tener un mejor rendimiento que el modelo de referencia, lo que daría como resultado un MAE menor.

# %%
# Almacene el MAE de la línea base en el conjunto de prueba.
print(f'Para nuestro modelo de Referencia MAE el error absoluto es')
print(performance['Baseline - Last'][1])
# Out:
# Para nuestro modelo de Referencia MAE el error absoluto es
# 0.08128398656845093

# %% [markdown]
# ### **Paso 18. Pronosticando con el Modelo de referencia de varios pasos**
# + Con la ventana de datos generada, ahora podemos centrarnos en implementar los modelos de línea base.
# + En esta situación, hay dos líneas base razonables:
#   + Predecir el último valor conocido para los próximos 24 pasos de tiempo.
#   + Predecir los últimos 24 pasos de tiempo para los próximos 24 pasos de tiempo.
# + Con eso en mente, implementemos la primera línea base, donde simplemente repetiremos el último valor conocido en los próximos 24 pasos de tiempo.

# %%
# **Paso 18. Pronosticando con el Modelo de referencia de varios pasos**
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %% [markdown]
# ### **a. PREDICCIÓN DEL ÚLTIMO VALOR CONOCIDO**
# + Para predecir el último valor conocido, definiremos una clase MultiStepLastBaseline que simplemente toma la entrada y repite el último valor de la secuencia de entrada en 24 pasos de tiempo.

# %%
class MultiStepLastBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index

    def call(self, inputs):
        if self.label_index is None: #Devuelve el último valor conocido de la columna de destino durante los próximos 24 pasos de tiempo.
            return tf.tile(inputs[:, -1:, :], [1, 24, 1]) # Si no se especifica ningún objetivo, devuelve el último valor conocido
            #de todas las columnas durante los próximos 24 pasos de tiempo
        return tf.tile(inputs[:, -1:, self.label_index:], [1, 24, 1])

# %% [markdown]
# ### **b. A continuación, inicializaremos la clase y especificaremos la columna de destino.**
# + Luego, repetiremos los mismos pasos que en la sección anterior, compilando el modelo y evaluándolo en el conjunto de validación y el conjunto de prueba.

# %%
ms_baseline_last = MultiStepLastBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance = {}
ms_performance = {}

ms_val_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.val)
ms_performance['Baseline - Last'] = ms_baseline_last.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 0s 3ms/step - loss: 0.1874 - mean_absolute_error: 0.3520

# %% [markdown]
# ### **c. Ahora podemos visualizar las predicciones utilizando el método de gráfico de DataWindow**
# + El resultado se muestra en la figura 13.10.

# %%
multi_window.plot(ms_baseline_last)

# %% [markdown]
# + **Figura 13.10 Predicción del último valor conocido para los próximos 24 pasos de tiempo. Podemos ver que las predicciones, que se muestran como cruces, corresponden al último valor de la secuencia de entrada, por lo que nuestra línea base se comporta como se esperaba.**
# + Nuevamente, podemos imprimir opcionalmente el MAE de la línea base. De la figura 13.10, podemos esperar que

# %%
# Almacene el MAE de la línea base en el conjunto de prueba.
print(f'Para nuestro modelo de Referencia MAE multipaso el error absoluto es')
print(ms_performance['Baseline - Last'][1])
# Out:
# Para nuestro modelo de Referencia MAE multipaso el error absoluto es
# 0.34706419706344604

# %% [markdown]
# + **Esto da un MAE de 0,347. Ahora veamos si podemos construir una mejor línea base simplemente repitiendo la secuencia de entrada.**

# %% [markdown]
# ### **Paso 19. REPETICIÓN DE LA SECUENCIA DE ENTRADA**
# + Implementemos una segunda línea base para los modelos de varios pasos, que simplemente devuelve la secuencia de entrada.
# + Esto significa que la predicción para las próximas 24 horas será simplemente la última de las 24 horas de datos conocidas.
# ### **a. Esto se implementa a través de la clase RepeatBaseline**

# %%
class RepeatBaseline(Model):
    def __init__(self, label_index=None):
        super().__init__()
        self.label_index = label_index

    def call(self, inputs):
        return inputs[:, :, self.label_index:]

# %% [markdown]
# ### **b. Ahora podemos inicializar el modelo de referencia y generar predicciones.**
# + Tenga en cuenta que la función de pérdida y la métrica de evaluación siguen siendo las mismas.

# %%
ms_baseline_repeat = RepeatBaseline(label_index=column_indices['traffic_volume'])

ms_baseline_repeat.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

ms_val_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.val)
ms_performance['Baseline - Repeat'] = ms_baseline_repeat.evaluate(multi_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 1s 5ms/step - loss: 0.2125 - mean_absolute_error: 0.3533

# %%
multi_window.plot(ms_baseline_repeat)

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **A continuación, podemos visualizar las predicciones. El resultado se muestra en la figura 13.11. Esta línea base funciona bien, lo cual es de esperar, ya que identificamos la estacionalidad diaria en el capítulo anterior. Esta línea base es el equivalente a predecir la última estación conocida.**

# %%
# Almacene el MAE de la línea base en el conjunto de prueba.
print(f'Para nuestro modelo de Referencia MAE multipaso el error absoluto es')
print(ms_performance['Baseline - Last'][1])
# Out:
# Para nuestro modelo de Referencia MAE multipaso el error absoluto es
# 0.34706419706344604

# %% [markdown]
# ### **Paso 20. Modelo de referencia de múltiples salidas**
# + Luego, utilizaremos la clase Baseline que definimos para el modelo de un solo paso.
# + Recuerde que esta clase puede generar el último valor conocido para una lista de objetivos.

# %%
# Tenga en cuenta que pasamos tanto temp como Traffic_volume, ya que esos son nuestros dos objetivos para el modelo de salida múltiple.
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume'])
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
print(column_indices['traffic_volume'])
print(column_indices['temp'])
# Out:
# 2
# 0

# %%
mo_baseline_last = Baseline(label_index=[0, 2])

mo_baseline_last.compile(loss=MeanSquaredError(), metrics=[MeanAbsoluteError()])

mo_val_performance = {}
mo_performance = {}

mo_val_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.val)
mo_performance['Baseline - Last'] = mo_baseline_last.evaluate(mo_wide_window.test, verbose=0)
# Out:
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0482

# %% [markdown]
# ### **Paso 21. Predicciones para nuestras variables objetivo**
# + Por último, podemos visualizar las predicciones en relación con los valores reales.
# + De forma predeterminada, nuestro método de gráfico mostrará el volumen de tráfico en el eje y, lo que nos permitirá visualizar rápidamente uno de nuestros objetivos, como se muestra en la figura 13.12.**

# %% [markdown]
# ### **a. Predicción para la variable traffic_volume**

# %%
### **a. Predicción para la variable traffic_volume**
mo_wide_window.plot(mo_baseline_last)

plt.savefig('figures', dpi=300)

# %% [markdown]
# ### **b. Predicción para la variable Temp**
# + La figura 13.12 no muestra nada sorprendente, ya que ya vimos estos resultados cuando construimos un modelo de referencia de un solo paso.
# + La particularidad del modelo de múltiples salidas es que también tenemos predicciones para la temperatura.
# + Por supuesto, también podemos visualizar las predicciones para la temperatura especificando el objetivo en el método de gráfico.
# + El resultado se muestra en la figura 13.13.

# %%
mo_wide_window.plot(model=mo_baseline_last, plot_col='temp')

# %% [markdown]
# + **Figura 13.13 Predicción del último valor conocido de la temperatura. Las predicciones (cruces) son iguales al punto de datos anterior, por lo que nuestro modelo de referencia se comporta como se esperaba.**

# %%
### **c. Error MAE**

# %%
# Almacene el MAE de la línea base en el conjunto de prueba.
print(f'Para nuestro modelo de Referencia MAE multipaso el error absoluto es')
print(mo_performance['Baseline - Last'][1])
# Out:
# Para nuestro modelo de Referencia MAE multipaso el error absoluto es
# 0.04710666462779045

# %% [markdown]
# ### **Paso 22. Implementación de un modelo lineal de un solo paso**
# + La función toma un modelo y una ventana de datos de la clase DataWindow.
# + La paciencia es la cantidad de épocas después de las cuales el modelo debe dejar de entrenarse si la pérdida de validación no mejora; max_epochs establece una cantidad máxima de épocas para entrenar el modelo.
# + Se realiza un seguimiento de la pérdida de validación para determinar si debemos aplicar una detención anticipada o no.
# + El MSE se utiliza como función de pérdida.
# + La detención anticipada se produce si 3 épocas consecutivas no reducen la pérdida de validación, según lo establecido por el parámetro de paciencia.
# + El modelo se ajusta al conjunto de entrenamiento.
# + El MAE se utiliza como métrica de error. Así es como comparamos el
# rendimiento de nuestros modelos. Un MAE más bajo significa un mejor modelo.
# + Utilizamos el conjunto
# de validación para calcular la
# pérdida de validación.
# + early_stopping se pasa como una
# devolución de llamada. Si la pérdida de
# validación no disminuye después de
# 3 épocas consecutivas, el
# modelo detiene el entrenamiento. Esto
# evita el sobreajuste.
# + El modelo puede entrenarse durante
# un máximo de 50 épocas, según lo
# establecido por el parámetro max_epochs.

# %%
def compile_and_fit(model, window, patience=3, max_epochs=50):
    early_stopping = EarlyStopping(monitor='val_loss',
                                   patience=patience,
                                   mode='min')

    model.compile(loss=MeanSquaredError(),
                  optimizer=Adam(),
                  metrics=[MeanAbsoluteError()])

    history = model.fit(window.train,
                       epochs=max_epochs,
                       validation_data=window.val,
                       callbacks=[early_stopping])

    return history

# %% [markdown]
# ### **Acerca del codigo usado**
# + Este fragmento de código se reutilizará en todos los capítulos de aprendizaje profundo, por lo que es importante comprender lo que está sucediendo.
# + La función compile_and_fit toma un modelo de aprendizaje profundo, una ventana de datos de la clase DataWindow, el parámetro de paciencia y el parámetro max_epochs.
# + El parámetro de paciencia se utiliza en la función early_stopping, que nos permite detener el entrenamiento del modelo si no hay mejoras en la pérdida de validación, como se especifica en el parámetro de monitor.
# + De esa manera, evitamos el tiempo de entrenamiento inútil y el sobreajuste.
# + Luego, se compila el modelo. En Keras, esto simplemente configura el modelo para especificar la función de pérdida que se utilizará, el optimizador y las métricas de evaluación.
# + En nuestro caso, utilizaremos el MSE como función de pérdida porque el error se eleva al cuadrado, lo que significa que el modelo se penaliza considerablemente por grandes diferencias entre los valores previstos y los reales.
# + Utilizaremos el optimizador *Adam* porque es un optimizador rápido y eficiente.
# + Por último, utilizaremos el MAE como métrica de evaluación para comparar el rendimiento de nuestros modelos, ya que lo utilizamos para evaluar nuestros modelos de referencia en el capítulo anterior y es fácil de interpretar.
# + Luego, el modelo se ajusta a los datos de entrenamiento de hasta 50 épocas, según lo establecido por el parámetro max_epochs.
# + La validación se realiza en el conjunto de validación y pasamos early_stopping como devolución de llamada.
# + De esa manera, Keras aplicará la detención temprana si ve que la pérdida de validación no ha disminuido después de 3 épocas consecutivas.
# + Con compile_and_fit en su lugar, podemos avanzar para construir realmente nuestro modelo lineal.
# + Utilizaremos el modelo secuencial de Keras, ya que nos permite apilar diferentes capas.
# + Dado que estamos construyendo un modelo lineal aquí, solo tenemos una capa: una capa densa, que es la capa más básica en el aprendizaje profundo.
# + Especificaremos la cantidad de unidades como 1, ya que el modelo debe generar solo un valor: la predicción del volumen de tráfico en el próximo paso de tiempo.

# %% [markdown]
# ### **Paso 23. Construyendo un modelo lineal - la capa más básica en el aprendizaje profundo**
# + Claramente, Keras facilita mucho la creación de modelos.
# + Una vez completado este paso, podemos entrenar el modelo mediante compile_and_fit y almacenar el rendimiento para compararlo posteriormente con la línea base.

# %%
linear = Sequential([
    Dense(units=1)
])

history = compile_and_fit(linear, single_step_window)

val_performance['Linear'] = linear.evaluate(single_step_window.val)
performance['Linear'] = linear.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.1589 - mean_absolute_error: 0.3283 - val_loss: 0.1034 - val_mean_absolute_error: 0.2659
# Epoch 2/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0776 - mean_absolute_error: 0.2244 - val_loss: 0.0639 - val_mean_absolute_error: 0.2080
# Epoch 3/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0503 - mean_absolute_error: 0.1796 - val_loss: 0.0453 - val_mean_absolute_error: 0.1734
# Epoch 4/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0358 - mean_absolute_error: 0.1505 - val_loss: 0.0335 - val_mean_absolute_error: 0.1478
# Epoch 5/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0264 - mean_absolute_error: 0.1277 - val_loss: 0.0250 - val_mean_absolute_error: 0.1261
# Epoch 6/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0201 - mean_absolute_error: 0.1092 - val_loss: 0.0191 - val_mean_absolute_error: 0.1088
# Epoch 7/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0159 - mean_absolute_error: 0.0953 - val_loss: 0.0153 - val_mean_absolute_error: 0.0950
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0134 - mean_absolute_error: 0.0861 - val_loss: 0.0129 - val_mean_absolute_error: 0.0846
# Epoch 9/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0118 - mean_absolute_error: 0.0803 - val_loss: 0.0115 - val_mean_absolute_error: 0.0791
# Epoch 10/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0109 - mean_absolute_error: 0.0765 - val_loss: 0.0106 - val_mean_absolute_error: 0.0739
# Epoch 11/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0103 - mean_absolute_error: 0.0738 - val_loss: 0.0101 - val_mean_absolute_error: 0.0708
# Epoch 12/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0099 - mean_absolute_error: 0.0718 - val_loss: 0.0097 - val_mean_absolute_error: 0.0683
# Epoch 13/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0097 - mean_absolute_error: 0.0703 - val_loss: 0.0094 - val_mean_absolute_error: 0.0683
# Epoch 14/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0095 - mean_absolute_error: 0.0694 - val_loss: 0.0093 - val_mean_absolute_error: 0.0675
# Epoch 15/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0094 - mean_absolute_error: 0.0685 - val_loss: 0.0092 - val_mean_absolute_error: 0.0675
# Epoch 16/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0093 - mean_absolute_error: 0.0682 - val_loss: 0.0091 - val_mean_absolute_error: 0.0685
# Epoch 17/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0093 - mean_absolute_error: 0.0680 - val_loss: 0.0090 - val_mean_absolute_error: 0.0676
# Epoch 18/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0678 - val_loss: 0.0090 - val_mean_absolute_error: 0.0666
# Epoch 19/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0676 - val_loss: 0.0090 - val_mean_absolute_error: 0.0674
# Epoch 20/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0092 - mean_absolute_error: 0.0675 - val_loss: 0.0090 - val_mean_absolute_error: 0.0666
# Epoch 21/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0092 - mean_absolute_error: 0.0675 - val_loss: 0.0090 - val_mean_absolute_error: 0.0659
# Epoch 22/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0674 - val_loss: 0.0090 - val_mean_absolute_error: 0.0669
# Epoch 23/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0092 - mean_absolute_error: 0.0674 - val_loss: 0.0090 - val_mean_absolute_error: 0.0671
# Epoch 24/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0092 - mean_absolute_error: 0.0674 - val_loss: 0.0090 - val_mean_absolute_error: 0.0662
# Epoch 25/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0092 - mean_absolute_error: 0.0674 - val_loss: 0.0090 - val_mean_absolute_error: 0.0666
# Epoch 26/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0092 - mean_absolute_error: 0.0673 - val_loss: 0.0090 - val_mean_absolute_error: 0.0666
# Epoch 27/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0092 - mean_absolute_error: 0.0674 - val_loss: 0.0090 - val_mean_absolute_error: 0.0675
# Epoch 28/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0092 - mean_absolute_error: 0.0674 - val_loss: 0.0090 - val_mean_absolute_error: 0.0661
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0090 - mean_absolute_error: 0.0661

# %% [markdown]
# ### **Paso 24. visualizar las predicciones - método plot de wide_window**
# + Opcionalmente, podemos visualizar las predicciones de nuestro modelo lineal utilizando el método plot de wide_window. El resultado se muestra en la figura 14.2.
# + el rendimiento de nuestros modelos en relación con las líneas base. Por ahora, pasemos a implementar los modelos lineales de múltiples pasos y de múltiples salidas.

# %%
wide_window.plot(linear)

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **Figura 14.2 Predicciones del volumen de tráfico utilizando el modelo lineal como modelo de un solo paso. Las predicciones (mostradas como cruces) son bastante precisas, y algunas predicciones se superponen a los valores reales (mostrados como cuadrados)**

# %% [markdown]
# # **Implementación de un modelo lineal de varios pasos**
# + Nuestro modelo lineal de un solo paso está construido y ahora podemos extenderlo a un modelo lineal de varios pasos.
# + Recordemos que en la situación de varios pasos, deseamos predecir las próximas 24 horas de datos utilizando una ventana de entrada de 24 horas de datos.
# + Nuestro objetivo sigue siendo el volumen de tráfico.
# + Este modelo se parecerá mucho al modelo lineal de un solo paso, pero esta vez utilizaremos 24 horas de entrada y 24 horas de predicciones de salida.
# + El modelo lineal de varios pasos se ilustra en la figura 14.3.
# + Como puede ver, el modelo toma 24 horas de cada característica, las combina en una sola capa y genera un tensor que contiene el pronóstico para las próximas 24 horas.
# + La implementación del modelo es fácil, ya que nuestro modelo solo contiene una única capa Dense.
# + Podemos inicializar opcionalmente los pesos a 0, lo que hace que el procedimiento de entrenamiento sea un poco más rápido.
# + Luego compilamos y ajustamos el modelo antes de almacenar sus métricas de evaluación en `ms_val_performance` y `ms_performance`.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Paso 25. Implementación de un modelo lineal de múltiples pasos**
#
# + Acabamos de crear un modelo lineal de varios pasos.
# + Puede que te sientas decepcionado, ya que el código es casi idéntico al del modelo lineal de un solo paso.
# + Esto se debe a nuestro trabajo de creación de la clase DataWindow y de la ventana adecuada de nuestros datos.
# + Una vez realizado ese paso, la creación de modelos se vuelve extremadamente fácil.
# + A continuación, implementaremos un modelo lineal de múltiples salidas.

# %%
mo_linear = Sequential([
    Dense(units=2)
])

history = compile_and_fit(mo_linear, mo_single_step_window)

mo_val_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.val)
mo_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.2300 - mean_absolute_error: 0.3861 - val_loss: 0.1240 - val_mean_absolute_error: 0.2915
# Epoch 2/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0795 - mean_absolute_error: 0.2247 - val_loss: 0.0534 - val_mean_absolute_error: 0.1787
# Epoch 3/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0349 - mean_absolute_error: 0.1381 - val_loss: 0.0270 - val_mean_absolute_error: 0.1181
# Epoch 4/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0193 - mean_absolute_error: 0.0963 - val_loss: 0.0172 - val_mean_absolute_error: 0.0902
# Epoch 5/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0133 - mean_absolute_error: 0.0769 - val_loss: 0.0125 - val_mean_absolute_error: 0.0751
# Epoch 6/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0102 - mean_absolute_error: 0.0659 - val_loss: 0.0097 - val_mean_absolute_error: 0.0653
# Epoch 7/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0083 - mean_absolute_error: 0.0579 - val_loss: 0.0079 - val_mean_absolute_error: 0.0576
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0520 - val_loss: 0.0066 - val_mean_absolute_error: 0.0515
# Epoch 9/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0062 - mean_absolute_error: 0.0478 - val_loss: 0.0059 - val_mean_absolute_error: 0.0472
# Epoch 10/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0057 - mean_absolute_error: 0.0450 - val_loss: 0.0054 - val_mean_absolute_error: 0.0442
# Epoch 11/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0054 - mean_absolute_error: 0.0429 - val_loss: 0.0051 - val_mean_absolute_error: 0.0423
# Epoch 12/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0052 - mean_absolute_error: 0.0417 - val_loss: 0.0049 - val_mean_absolute_error: 0.0409
# Epoch 13/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0051 - mean_absolute_error: 0.0408 - val_loss: 0.0048 - val_mean_absolute_error: 0.0396
# Epoch 14/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0402 - val_loss: 0.0047 - val_mean_absolute_error: 0.0402
# Epoch 15/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0399 - val_loss: 0.0047 - val_mean_absolute_error: 0.0392
# Epoch 16/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0397 - val_loss: 0.0047 - val_mean_absolute_error: 0.0396
# Epoch 17/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0396 - val_loss: 0.0047 - val_mean_absolute_error: 0.0399
# Epoch 18/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0046 - val_mean_absolute_error: 0.0398
# Epoch 19/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0394
# Epoch 20/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0392
# Epoch 21/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0385
# Epoch 22/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0388
# Epoch 23/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0391
# Epoch 24/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0395
# Epoch 25/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0388
# Epoch 26/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0395
# Epoch 27/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0388
# Epoch 28/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0389
# Epoch 29/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0391
# Epoch 30/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0394
# Epoch 31/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0393
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0046 - mean_absolute_error: 0.0393

# %% [markdown]
# # **Implementación de un modelo lineal de múltiples salidas**
# + El modelo lineal de múltiples salidas devolverá predicciones para el volumen de tráfico y la temperatura.
# + La entrada es el intervalo de tiempo actual y las predicciones son para el siguiente intervalo de tiempo.
# + La arquitectura del modelo se muestra en la figura 14.4.
# + Allí, puede ver que nuestro modelo lineal de múltiples salidas tomará todas las características en t = 0, las combinará en una sola capa y generará como salida tanto la temperatura como el volumen de tráfico en el siguiente intervalo de tiempo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Paso 26. Implementación de un modelo lineal de múltiples salidas**
# + Hasta este punto, solo hemos predicho el volumen de tráfico, lo que significa que solo teníamos un objetivo, por lo que usamos la capa Dense(units=1).
# + En este caso, dado que debemos generar una predicción para dos objetivos, nuestra capa será Dense(units=2).
# + Como antes, entrenaremos el modelo y almacenaremos su rendimiento para compararlo más tarde con la línea base y la red neuronal profunda.
# + Nuevamente, puedes ver lo fácil que es construir un modelo de aprendizaje profundo en Keras, especialmente cuando tenemos la ventana de datos adecuada como entrada.
# + Con nuestros *modelos lineales de un solo paso, de varios pasos y de múltiples salidas listos*, ahora podemos avanzar hacia la implementación de una arquitectura más compleja: una red neuronal profunda

# %%
mo_linear = Sequential([
Dense(units=2)
])
history = compile_and_fit(mo_linear, mo_single_step_window)
mo_val_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.val)
mo_performance['Linear'] = mo_linear.evaluate(mo_single_step_window.test,verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 2s 4ms/step - loss: 1.1675 - mean_absolute_error: 0.7726 - val_loss: 0.5679 - val_mean_absolute_error: 0.5026
# Epoch 2/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.2919 - mean_absolute_error: 0.3501 - val_loss: 0.1765 - val_mean_absolute_error: 0.2804
# Epoch 3/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.1211 - mean_absolute_error: 0.2369 - val_loss: 0.0984 - val_mean_absolute_error: 0.2147
# Epoch 4/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0753 - mean_absolute_error: 0.1874 - val_loss: 0.0622 - val_mean_absolute_error: 0.1699
# Epoch 5/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0471 - mean_absolute_error: 0.1466 - val_loss: 0.0382 - val_mean_absolute_error: 0.1312
# Epoch 6/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0286 - mean_absolute_error: 0.1122 - val_loss: 0.0232 - val_mean_absolute_error: 0.0996
# Epoch 7/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0178 - mean_absolute_error: 0.0858 - val_loss: 0.0150 - val_mean_absolute_error: 0.0765
# Epoch 8/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0122 - mean_absolute_error: 0.0685 - val_loss: 0.0109 - val_mean_absolute_error: 0.0622
# Epoch 9/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0096 - mean_absolute_error: 0.0593 - val_loss: 0.0091 - val_mean_absolute_error: 0.0550
# Epoch 10/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0085 - mean_absolute_error: 0.0550 - val_loss: 0.0082 - val_mean_absolute_error: 0.0518
# Epoch 11/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0080 - mean_absolute_error: 0.0527 - val_loss: 0.0077 - val_mean_absolute_error: 0.0500
# Epoch 12/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0077 - mean_absolute_error: 0.0513 - val_loss: 0.0073 - val_mean_absolute_error: 0.0487
# Epoch 13/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0074 - mean_absolute_error: 0.0501 - val_loss: 0.0070 - val_mean_absolute_error: 0.0477
# Epoch 14/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0071 - mean_absolute_error: 0.0489 - val_loss: 0.0067 - val_mean_absolute_error: 0.0465
# Epoch 15/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0068 - mean_absolute_error: 0.0478 - val_loss: 0.0064 - val_mean_absolute_error: 0.0455
# Epoch 16/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0065 - mean_absolute_error: 0.0467 - val_loss: 0.0061 - val_mean_absolute_error: 0.0447
# Epoch 17/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0062 - mean_absolute_error: 0.0455 - val_loss: 0.0058 - val_mean_absolute_error: 0.0436
# Epoch 18/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0059 - mean_absolute_error: 0.0444 - val_loss: 0.0055 - val_mean_absolute_error: 0.0428
# Epoch 19/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0057 - mean_absolute_error: 0.0433 - val_loss: 0.0053 - val_mean_absolute_error: 0.0415
# Epoch 20/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0055 - mean_absolute_error: 0.0423 - val_loss: 0.0051 - val_mean_absolute_error: 0.0418
# Epoch 21/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0053 - mean_absolute_error: 0.0415 - val_loss: 0.0050 - val_mean_absolute_error: 0.0399
# Epoch 22/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0051 - mean_absolute_error: 0.0408 - val_loss: 0.0048 - val_mean_absolute_error: 0.0401
# Epoch 23/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0051 - mean_absolute_error: 0.0404 - val_loss: 0.0048 - val_mean_absolute_error: 0.0398
# Epoch 24/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0050 - mean_absolute_error: 0.0400 - val_loss: 0.0047 - val_mean_absolute_error: 0.0399
# Epoch 25/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0050 - mean_absolute_error: 0.0398 - val_loss: 0.0047 - val_mean_absolute_error: 0.0395
# Epoch 26/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0047 - val_mean_absolute_error: 0.0395
# Epoch 27/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0396 - val_loss: 0.0046 - val_mean_absolute_error: 0.0391
# Epoch 28/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0395 - val_loss: 0.0046 - val_mean_absolute_error: 0.0391
# Epoch 29/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0047 - val_mean_absolute_error: 0.0397
# Epoch 30/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0047 - val_mean_absolute_error: 0.0400
# Epoch 31/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0395
# Epoch 32/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0392
# Epoch 33/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0389
# Epoch 34/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0396
# Epoch 35/50
# 384/384 [==============================] - 3s 7ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0391
# Epoch 36/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0392
# Epoch 37/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0047 - val_mean_absolute_error: 0.0399
# Epoch 38/50
# 384/384 [==============================] - 1s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0394 - val_loss: 0.0046 - val_mean_absolute_error: 0.0395
# Epoch 39/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0049 - mean_absolute_error: 0.0393 - val_loss: 0.0046 - val_mean_absolute_error: 0.0392
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0046 - mean_absolute_error: 0.0392

# %% [markdown]
# # **Implementación de una red neuronal profunda**
# + Una vez implementados nuestros tres tipos de modelos lineales, es hora de pasar a las redes neuronales profundas.
# + Se ha demostrado empíricamente que agregar capas ocultas en las redes neuronales ayuda a lograr mejores resultados.
# + Además, *introduciremos una función de activación no lineal para capturar relaciones no lineales en los datos*.
# + Los modelos lineales no tienen capas ocultas; el modelo tenía una capa de entrada y una capa de salida.
# + En una red neuronal profunda **(DNN)**, agregaremos más capas entre las capas de entrada y salida, llamadas capas ocultas.
# + Esta diferencia en la arquitectura se destaca en la figura 14.5.
# + ***La idea detrás de agregar capas a la red es que le da al modelo más oportunidades de aprender, lo que generalmente da como resultado que el modelo generalice mejor en datos no vistos, mejorando así su rendimiento.***
# + *Por supuesto, con capas agregadas, el modelo necesariamente se entrena durante más tiempo y, por lo tanto, se supone que aprende mejor.*
# + **Cada círculo en una capa oculta representa una neurona, y cada neurona tiene una función de activación.**
# + La cantidad de neuronas es igual a la cantidad de unidades que se pasan como argumento en la capa densa en Keras.
# + Por lo general, establecemos la cantidad de unidades, o neuronas,
# como una potencia de 2, ya que es más eficiente computacionalmente: los cálculos en la CPU y la GPU se realizan en tamaños de lote que también son potencias de 2.
#
#
# ### **Antes de implementar una red neuronal profunda, debemos abordar la función de activación en cada neurona de las capas ocultas.**
# + La función de activación define la salida de cada neurona en función de la entrada.
# + Por lo tanto, si deseamos modelar relaciones no lineales, debemos utilizar una función de activación no lineal.
# + ***La función de activación se encuentra en cada neurona de la red neuronal y es la encargada de generar una salida a partir de los datos de entrada.***
# + *Si se utiliza una función de activación lineal, el modelo solo modelará relaciones lineales.*
# + *Por lo tanto, para modelar relaciones no lineales en los datos, debemos utilizar una función de activación no lineal.*
# + Algunos ejemplos de funciones de activación no lineales son `ReLU, softmax o tanh`.
# + *En nuestro caso, utilizaremos la función de activación de la Unidad Lineal Rectificada (ReLU)*.
# + Esta función de activación no lineal básicamente devuelve la parte positiva de su entrada o 0, como se define en la ecuación 14.2.
# + **Ecuación 14.2**
# $$f(x) = x+ = max (0, x)$$
# + Esta función de activación tiene muchas ventajas, como una mejor propagación del gradiente, un cálculo más eficiente y una invariancia de escala.
# + Por todas esas razones, ahora es la función de activación más utilizada en el aprendizaje profundo y la utilizaremos siempre que tengamos una capa densa que sea una capa oculta.
# + Ahora estamos listos para implementar una red neuronal profunda en Keras.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **Paso 27. Implementación de una red neuronal profunda como un modelo de un solo paso**
# + Primera capa oculta con 64 neuronas. Especifique que la función de activación sea ReLU.
# + La capa de salida tiene solo una neurona, ya que solo generamos un valor.
# + Con el modelo definido, ahora podemos compilarlo, entrenarlo y registrar su rendimiento para compararlo con la línea base y el modelo lineal.

# %%
# **Paso 27. Implementación de una red neuronal profunda como un modelo de un solo paso**
dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=1)
])

history = compile_and_fit(dense, single_step_window)

val_performance['Dense'] = dense.evaluate(single_step_window.val)
performance['Dense'] = dense.evaluate(single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 3s 5ms/step - loss: 0.0106 - mean_absolute_error: 0.0695 - val_loss: 0.0044 - val_mean_absolute_error: 0.0517
# Epoch 2/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0039 - mean_absolute_error: 0.0461 - val_loss: 0.0030 - val_mean_absolute_error: 0.0413
# Epoch 3/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0032 - mean_absolute_error: 0.0408 - val_loss: 0.0025 - val_mean_absolute_error: 0.0378
# Epoch 4/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0028 - mean_absolute_error: 0.0381 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 5/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0365 - val_loss: 0.0020 - val_mean_absolute_error: 0.0332
# Epoch 6/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0026 - mean_absolute_error: 0.0361 - val_loss: 0.0020 - val_mean_absolute_error: 0.0329
# Epoch 7/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0355 - val_loss: 0.0023 - val_mean_absolute_error: 0.0358
# Epoch 8/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0024 - mean_absolute_error: 0.0345 - val_loss: 0.0018 - val_mean_absolute_error: 0.0306
# Epoch 9/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0340 - val_loss: 0.0023 - val_mean_absolute_error: 0.0365
# Epoch 10/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0023 - mean_absolute_error: 0.0337 - val_loss: 0.0021 - val_mean_absolute_error: 0.0342
# Epoch 11/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0022 - mean_absolute_error: 0.0331 - val_loss: 0.0018 - val_mean_absolute_error: 0.0308
# 110/110 [==============================] - 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0308

# %% [markdown]
# ### **Paso 28. Implementación de una red neuronal profunda como un modelo de un solo paso - Predicciones**
# + Por supuesto, podemos echar un vistazo a las predicciones del modelo utilizando el método de gráficos, como se muestra en la figura 14.6. Nuestra red neuronal profunda parece estar haciendo predicciones bastante precisas.

# %%
wide_window.plot(dense)

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **Figura 14.6 Predicción del volumen de tráfico utilizando una red neuronal profunda como modelo de un solo paso. Aquí, incluso más predicciones (mostradas como cruces) se superponen con los valores reales (mostrados como cuadrados), lo que sugiere que el modelo está haciendo predicciones muy precisas.**

# %% [markdown]
# ### **Paso 29. Grafico de los Errores MAE - DNN vs Modeleo Baeline**
# + Comparemos el MAE de la DNN con el modelo lineal y la línea base que construimos en el capítulo 13.
# + El resultado se muestra en la figura 14.7.

# %%
mae_val = [v[1] for v in val_performance.values()]
mae_test = [v[1] for v in performance.values()]

x = np.arange(len(performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **Figura 14.7 El MAE de todos los modelos de un solo paso hasta el momento. El modelo lineal tiene un mejor rendimiento que el modelo de referencia, que solo predice el último valor conocido. El modelo denso supera a ambos modelos, ya que tiene el MAE más bajo.**

# %% [markdown]
# ### **Paso 30. Implementación de una red neuronal profunda como un modelo de varios pasos**

# %%
ms_dense = Sequential([
    Dense(64, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_dense, multi_window)

ms_val_performance['Dense'] = ms_dense.evaluate(multi_window.val)
ms_performance['Dense'] = ms_dense.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 4s 8ms/step - loss: 0.0294 - mean_absolute_error: 0.1093 - val_loss: 0.0158 - val_mean_absolute_error: 0.0831
# Epoch 2/50
# 383/383 [==============================] - 3s 8ms/step - loss: 0.0136 - mean_absolute_error: 0.0776 - val_loss: 0.0150 - val_mean_absolute_error: 0.0791
# Epoch 3/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0132 - mean_absolute_error: 0.0768 - val_loss: 0.0144 - val_mean_absolute_error: 0.0797
# Epoch 4/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0128 - mean_absolute_error: 0.0760 - val_loss: 0.0140 - val_mean_absolute_error: 0.0781
# Epoch 5/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0126 - mean_absolute_error: 0.0753 - val_loss: 0.0137 - val_mean_absolute_error: 0.0772
# Epoch 6/50
# 383/383 [==============================] - 4s 10ms/step - loss: 0.0125 - mean_absolute_error: 0.0748 - val_loss: 0.0137 - val_mean_absolute_error: 0.0759
# Epoch 7/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0123 - mean_absolute_error: 0.0742 - val_loss: 0.0138 - val_mean_absolute_error: 0.0803
# Epoch 8/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0739 - val_loss: 0.0142 - val_mean_absolute_error: 0.0768
# Epoch 9/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0736 - val_loss: 0.0133 - val_mean_absolute_error: 0.0773
# Epoch 10/50
# 383/383 [==============================] - 2s 6ms/step - loss: 0.0122 - mean_absolute_error: 0.0736 - val_loss: 0.0135 - val_mean_absolute_error: 0.0748
# Epoch 11/50
# 383/383 [==============================] - 3s 9ms/step - loss: 0.0121 - mean_absolute_error: 0.0734 - val_loss: 0.0136 - val_mean_absolute_error: 0.0761
# Epoch 12/50
# 383/383 [==============================] - 2s 5ms/step - loss: 0.0120 - mean_absolute_error: 0.0730 - val_loss: 0.0134 - val_mean_absolute_error: 0.0751
# 109/109 [==============================] - 0s 3ms/step - loss: 0.0134 - mean_absolute_error: 0.0751

# %%
wide_window.plot(ms_dense)

plt.savefig('figures', dpi=300)

# %%
ms_mae_val = [v[1] for v in ms_val_performance.values()]
ms_mae_test = [v[1] for v in ms_performance.values()]

x = np.arange(len(ms_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=ms_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **En la figura 14.8 verá que tanto el modelo lineal como la red neuronal profunda superan las dos líneas base que construimos para la tarea de varios pasos en el capítulo 13. Nuevamente, la red neuronal profunda tiene el MAE más bajo de todos, lo que significa que es el modelo de mayor rendimiento por ahora.**

# %% [markdown]
# # **Paso 31. Implementación de una red neuronal profunda como un modelo de múltiples salidas**

# %%
mo_dense = Sequential([
    Dense(units=64, activation='relu'),
    Dense(units=64, activation='relu'),
    Dense(units=2)
])

history = compile_and_fit(mo_dense, mo_single_step_window)

mo_val_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.val)
mo_performance['Dense'] = mo_dense.evaluate(mo_single_step_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 3s 6ms/step - loss: 0.0158 - mean_absolute_error: 0.0677 - val_loss: 0.0029 - val_mean_absolute_error: 0.0337
# Epoch 2/50
# 384/384 [==============================] - 2s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0332 - val_loss: 0.0022 - val_mean_absolute_error: 0.0307
# Epoch 3/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0296 - val_loss: 0.0017 - val_mean_absolute_error: 0.0265
# Epoch 4/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0274 - val_loss: 0.0014 - val_mean_absolute_error: 0.0238
# Epoch 5/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0018 - mean_absolute_error: 0.0260 - val_loss: 0.0013 - val_mean_absolute_error: 0.0230
# Epoch 6/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 0.0012 - val_mean_absolute_error: 0.0229
# Epoch 7/50
# 384/384 [==============================] - 3s 8ms/step - loss: 0.0016 - mean_absolute_error: 0.0247 - val_loss: 0.0011 - val_mean_absolute_error: 0.0219
# Epoch 8/50
# 384/384 [==============================] - 2s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0244 - val_loss: 0.0013 - val_mean_absolute_error: 0.0239
# Epoch 9/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# Epoch 10/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.0011 - val_mean_absolute_error: 0.0213
# Epoch 11/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0235 - val_loss: 0.0011 - val_mean_absolute_error: 0.0207
# Epoch 12/50
# 384/384 [==============================] - 2s 5ms/step - loss: 0.0015 - mean_absolute_error: 0.0234 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# 110/110 [==============================] - 1s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0244

# %%
mo_mae_val = [v[1] for v in mo_val_performance.values()]
mo_mae_test = [v[1] for v in mo_performance.values()]

x = np.arange(len(mo_performance))

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=mo_performance.keys())
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# # **15.3.1. Implementación de un LSTM como un modelo de un solo paso**
# ### **Paso 32. Implementación de un LSTM como un modelo de un solo paso**
# + Comenzaremos por implementar la arquitectura LSTM como un modelo de un solo paso.
# + En este caso, utilizaremos 24 horas de datos como entrada para predecir el siguiente paso de tiempo.
# + De esa manera, hay una secuencia de tiempo que puede ser procesada por el LSTM, lo que nos permite aprovechar la información pasada para hacer una predicción futura.
# + Primero, debemos crear una ventana de datos para entrenar el modelo.
# + Esta será una ventana amplia, con 24 horas de datos como entrada.
# + Para fines de representación gráfica, el ancho de etiqueta también es 24, de modo que podamos comparar las predicciones con los valores reales en 24 pasos de tiempo.
# + Tenga en cuenta que este sigue siendo un modelo de un solo paso, por lo que en 24 horas el modelo solo predecirá un paso de tiempo a la vez, al igual que un pronóstico continuo.

# %%
plt.rcParams['figure.figsize'] = (10, 7.5)
plt.rcParams['axes.grid'] = False
tf.random.set_seed(42)
np.random.seed(42)

# %%
train_df = pd.read_csv('/content/train.csv', index_col=0)
val_df = pd.read_csv('/content/val.csv', index_col=0)
test_df = pd.read_csv('/content/test.csv', index_col=0)

print(train_df.shape, val_df.shape, test_df.shape)
# Out:
# (12285, 5) (3510, 5) (1756, 5)

# %%
single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['traffic_volume'])
wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['traffic_volume'])

# %% [markdown]
# + Luego, debemos definir nuestro modelo LSTM en Keras.
# + Nuevamente, utilizaremos el modelo secuencial para permitirnos apilar diferentes capas en nuestra red.
# + Keras viene convenientemente con la capa LSTM, que implementa un LSTM.
# + Estableceremos `return_sequences` en True, ya que esto le indica a Keras que use información anterior de la secuencia, en forma de estado oculto y estado de celda, que cubrimos anteriormente.
# + Finalmente, definiremos la capa de salida, que es simplemente una capa densa con una unidad porque estamos pronosticando solo el volumen de tráfico.

# %%
lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units=1)
])
# Es así de simple. Ahora podemos entrenar el modelo utilizando la función compile_and_fit
# y almacenar su rendimiento en los conjuntos de validación y prueba.
history = compile_and_fit(lstm_model, wide_window)

val_performance = {}
performance = {}

val_performance['LSTM'] = lstm_model.evaluate(wide_window.val)
performance['LSTM'] = lstm_model.evaluate(wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 9s 15ms/step - loss: 0.0419 - mean_absolute_error: 0.1453 - val_loss: 0.0178 - val_mean_absolute_error: 0.0980
# Epoch 2/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0122 - mean_absolute_error: 0.0810 - val_loss: 0.0088 - val_mean_absolute_error: 0.0678
# Epoch 3/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0072 - mean_absolute_error: 0.0610 - val_loss: 0.0059 - val_mean_absolute_error: 0.0566
# Epoch 4/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0055 - mean_absolute_error: 0.0534 - val_loss: 0.0046 - val_mean_absolute_error: 0.0504
# Epoch 5/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0048 - mean_absolute_error: 0.0496 - val_loss: 0.0040 - val_mean_absolute_error: 0.0460
# Epoch 6/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0042 - mean_absolute_error: 0.0461 - val_loss: 0.0035 - val_mean_absolute_error: 0.0427
# Epoch 7/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0037 - mean_absolute_error: 0.0428 - val_loss: 0.0031 - val_mean_absolute_error: 0.0396
# Epoch 8/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0033 - mean_absolute_error: 0.0401 - val_loss: 0.0029 - val_mean_absolute_error: 0.0382
# Epoch 9/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0031 - mean_absolute_error: 0.0384 - val_loss: 0.0026 - val_mean_absolute_error: 0.0354
# Epoch 10/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0029 - mean_absolute_error: 0.0372 - val_loss: 0.0024 - val_mean_absolute_error: 0.0345
# Epoch 11/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0028 - mean_absolute_error: 0.0360 - val_loss: 0.0023 - val_mean_absolute_error: 0.0332
# Epoch 12/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0027 - mean_absolute_error: 0.0351 - val_loss: 0.0022 - val_mean_absolute_error: 0.0323
# Epoch 13/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0026 - mean_absolute_error: 0.0342 - val_loss: 0.0022 - val_mean_absolute_error: 0.0323
# Epoch 14/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0025 - mean_absolute_error: 0.0333 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 15/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0024 - mean_absolute_error: 0.0328 - val_loss: 0.0021 - val_mean_absolute_error: 0.0322
# Epoch 16/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0023 - mean_absolute_error: 0.0322 - val_loss: 0.0019 - val_mean_absolute_error: 0.0296
# Epoch 17/50
# 384/384 [==============================] - 7s 18ms/step - loss: 0.0023 - mean_absolute_error: 0.0316 - val_loss: 0.0024 - val_mean_absolute_error: 0.0362
# Epoch 18/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0313 - val_loss: 0.0019 - val_mean_absolute_error: 0.0297
# Epoch 19/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0308 - val_loss: 0.0018 - val_mean_absolute_error: 0.0285
# Epoch 20/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0306 - val_loss: 0.0018 - val_mean_absolute_error: 0.0290
# Epoch 21/50
# 384/384 [==============================] - 6s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0303 - val_loss: 0.0018 - val_mean_absolute_error: 0.0294
# Epoch 22/50
# 384/384 [==============================] - 6s 17ms/step - loss: 0.0021 - mean_absolute_error: 0.0300 - val_loss: 0.0017 - val_mean_absolute_error: 0.0282
# Epoch 23/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0020 - mean_absolute_error: 0.0297 - val_loss: 0.0016 - val_mean_absolute_error: 0.0271
# Epoch 24/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0020 - mean_absolute_error: 0.0295 - val_loss: 0.0016 - val_mean_absolute_error: 0.0273
# Epoch 25/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0020 - mean_absolute_error: 0.0293 - val_loss: 0.0017 - val_mean_absolute_error: 0.0274
# Epoch 26/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0291 - val_loss: 0.0017 - val_mean_absolute_error: 0.0289
# Epoch 27/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0020 - mean_absolute_error: 0.0291 - val_loss: 0.0016 - val_mean_absolute_error: 0.0275
# Epoch 28/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0288 - val_loss: 0.0017 - val_mean_absolute_error: 0.0289
# Epoch 29/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0019 - mean_absolute_error: 0.0287 - val_loss: 0.0016 - val_mean_absolute_error: 0.0267
# Epoch 30/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0284 - val_loss: 0.0015 - val_mean_absolute_error: 0.0263
# Epoch 31/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0019 - mean_absolute_error: 0.0284 - val_loss: 0.0016 - val_mean_absolute_error: 0.0268
# Epoch 32/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0019 - mean_absolute_error: 0.0283 - val_loss: 0.0016 - val_mean_absolute_error: 0.0273
# Epoch 33/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0018 - mean_absolute_error: 0.0282 - val_loss: 0.0016 - val_mean_absolute_error: 0.0273
# 109/109 [==============================] - 1s 5ms/step - loss: 0.0016 - mean_absolute_error: 0.0273

# %% [markdown]
# + **Opcionalmente, podemos visualizar las predicciones de nuestro modelo en tres secuencias muestreadas utilizando el método de representación gráfica de nuestra ventana de datos. El resultado se muestra en la figura 15.9.**

# %%
wide_window.plot(lstm_model)

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **La figura 15.9 muestra que tenemos un modelo de alto rendimiento que genera predicciones precisas. Por supuesto, esta visualización solo incluye tres secuencias muestreadas de 24 horas, por lo que vamos a visualizar el rendimiento del modelo en todos los conjuntos de validación y prueba y compararlo con los modelos anteriores que hemos creado hasta ahora.**

# %%
mae_val.append(val_performance['LSTM'][1])
mae_test.append(performance['LSTM'][1])


x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']



fig, ax = plt.subplots()
ax.bar(x - 0.15, mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')





for index, value in enumerate(mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

for index, value in enumerate(mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.1)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **Figura 15.10 Error absoluto medio (MAE) de todos los modelos de un solo paso construidos hasta ahora. Por ahora, el LSTM es el modelo ganador, ya que tiene el MAE más bajo tanto en el conjunto de validación como en el de prueba.**

# %% [markdown]
# # **15.3.2. Implementación de un LSTM como un modelo de varios pasos.**
#
# ### **Paso 33. Implementación de un LSTM como un modelo de varios pasos**
# + Pasaremos a implementar la arquitectura LSTM como un modelo de varios pasos.
# + En este caso, deseamos predecir el volumen de tráfico para las próximas 24 horas, utilizando una ventana de entrada de 24 horas.
# + Primero, definiremos la ventana de tiempo para alimentar nuestro modelo.
# + El `input_width` y el `label_width` son ambos 24, ya que queremos ingresar 24 horas de datos y evaluar las predicciones también en 24 horas de datos.
# + Esta vez, el cambio también es 24, lo que especifica que el modelo debe generar predicciones para las próximas 24 horas en una sola toma.
# + A continuación, definiremos nuestro modelo en Keras.
# + Del capítulo 14, es posible que recuerdes que el proceso de definición del modelo de varios pasos y del modelo de un solo paso fue exactamente el mismo.
# + Lo mismo es cierto aquí.
# + Seguimos usando el modelo secuencial, junto con la capa LSTM y una capa de salida densa con una unidad.
# + Una vez que esté definido, entrenaremos el modelo y almacenaremos sus métricas de evaluación para comparar.
# + A esta altura, ya deberías estar familiarizado con este flujo de trabajo.
# + Podemos visualizar las predicciones del modelo utilizando el método plot, como se muestra en la figura 15.11.

# %%
multi_window = DataWindow(input_width=24, label_width=24, shift=24, label_columns=['traffic_volume'])

# %%
ms_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(1, kernel_initializer=tf.initializers.zeros),
])

history = compile_and_fit(ms_lstm_model, multi_window)

ms_val_performance = {}
ms_performance = {}

ms_val_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.val)
ms_performance['LSTM'] = ms_lstm_model.evaluate(multi_window.test, verbose=0)
# Out:
# Epoch 1/50
# 383/383 [==============================] - 8s 15ms/step - loss: 0.0455 - mean_absolute_error: 0.1523 - val_loss: 0.0209 - val_mean_absolute_error: 0.1001
# Epoch 2/50
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0167 - mean_absolute_error: 0.0889 - val_loss: 0.0180 - val_mean_absolute_error: 0.0924
# Epoch 3/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0150 - mean_absolute_error: 0.0827 - val_loss: 0.0165 - val_mean_absolute_error: 0.0835
# Epoch 4/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0143 - mean_absolute_error: 0.0800 - val_loss: 0.0163 - val_mean_absolute_error: 0.0827
# Epoch 5/50
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0138 - mean_absolute_error: 0.0783 - val_loss: 0.0163 - val_mean_absolute_error: 0.0888
# Epoch 6/50
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0134 - mean_absolute_error: 0.0770 - val_loss: 0.0155 - val_mean_absolute_error: 0.0794
# Epoch 7/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0133 - mean_absolute_error: 0.0760 - val_loss: 0.0148 - val_mean_absolute_error: 0.0784
# Epoch 8/50
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0130 - mean_absolute_error: 0.0751 - val_loss: 0.0146 - val_mean_absolute_error: 0.0805
# Epoch 9/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0128 - mean_absolute_error: 0.0742 - val_loss: 0.0144 - val_mean_absolute_error: 0.0787
# Epoch 10/50
# 383/383 [==============================] - 7s 17ms/step - loss: 0.0127 - mean_absolute_error: 0.0737 - val_loss: 0.0145 - val_mean_absolute_error: 0.0811
# Epoch 11/50
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0126 - mean_absolute_error: 0.0733 - val_loss: 0.0143 - val_mean_absolute_error: 0.0764
# Epoch 12/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0125 - mean_absolute_error: 0.0730 - val_loss: 0.0147 - val_mean_absolute_error: 0.0808
# Epoch 13/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0124 - mean_absolute_error: 0.0725 - val_loss: 0.0141 - val_mean_absolute_error: 0.0766
# Epoch 14/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0123 - mean_absolute_error: 0.0721 - val_loss: 0.0139 - val_mean_absolute_error: 0.0777
# Epoch 15/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0122 - mean_absolute_error: 0.0720 - val_loss: 0.0137 - val_mean_absolute_error: 0.0760
# Epoch 16/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0121 - mean_absolute_error: 0.0716 - val_loss: 0.0136 - val_mean_absolute_error: 0.0755
# Epoch 17/50
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0120 - mean_absolute_error: 0.0713 - val_loss: 0.0136 - val_mean_absolute_error: 0.0747
# Epoch 18/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0119 - mean_absolute_error: 0.0706 - val_loss: 0.0136 - val_mean_absolute_error: 0.0777
# Epoch 19/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0118 - mean_absolute_error: 0.0704 - val_loss: 0.0136 - val_mean_absolute_error: 0.0733
# Epoch 20/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0117 - mean_absolute_error: 0.0702 - val_loss: 0.0131 - val_mean_absolute_error: 0.0727
# Epoch 21/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0115 - mean_absolute_error: 0.0692 - val_loss: 0.0133 - val_mean_absolute_error: 0.0764
# Epoch 22/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0113 - mean_absolute_error: 0.0687 - val_loss: 0.0133 - val_mean_absolute_error: 0.0769
# Epoch 23/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0112 - mean_absolute_error: 0.0683 - val_loss: 0.0128 - val_mean_absolute_error: 0.0720
# Epoch 24/50
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0109 - mean_absolute_error: 0.0673 - val_loss: 0.0124 - val_mean_absolute_error: 0.0706
# Epoch 25/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0108 - mean_absolute_error: 0.0668 - val_loss: 0.0123 - val_mean_absolute_error: 0.0700
# Epoch 26/50
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0107 - mean_absolute_error: 0.0663 - val_loss: 0.0122 - val_mean_absolute_error: 0.0697
# Epoch 27/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0105 - mean_absolute_error: 0.0659 - val_loss: 0.0120 - val_mean_absolute_error: 0.0682
# Epoch 28/50
# 383/383 [==============================] - 7s 17ms/step - loss: 0.0104 - mean_absolute_error: 0.0652 - val_loss: 0.0121 - val_mean_absolute_error: 0.0687
# Epoch 29/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0103 - mean_absolute_error: 0.0650 - val_loss: 0.0118 - val_mean_absolute_error: 0.0679
# Epoch 30/50
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0103 - mean_absolute_error: 0.0648 - val_loss: 0.0122 - val_mean_absolute_error: 0.0714
# Epoch 31/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0102 - mean_absolute_error: 0.0643 - val_loss: 0.0115 - val_mean_absolute_error: 0.0688
# Epoch 32/50
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0101 - mean_absolute_error: 0.0640 - val_loss: 0.0117 - val_mean_absolute_error: 0.0683
# Epoch 33/50
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0100 - mean_absolute_error: 0.0634 - val_loss: 0.0117 - val_mean_absolute_error: 0.0669
# Epoch 34/50
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0100 - mean_absolute_error: 0.0634 - val_loss: 0.0115 - val_mean_absolute_error: 0.0668
# Epoch 35/50
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0099 - mean_absolute_error: 0.0632 - val_loss: 0.0115 - val_mean_absolute_error: 0.0655
# Epoch 36/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0099 - mean_absolute_error: 0.0631 - val_loss: 0.0114 - val_mean_absolute_error: 0.0666
# Epoch 37/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0098 - mean_absolute_error: 0.0628 - val_loss: 0.0115 - val_mean_absolute_error: 0.0696
# Epoch 38/50
# 383/383 [==============================] - 6s 15ms/step - loss: 0.0098 - mean_absolute_error: 0.0626 - val_loss: 0.0113 - val_mean_absolute_error: 0.0657
# Epoch 39/50
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0097 - mean_absolute_error: 0.0623 - val_loss: 0.0116 - val_mean_absolute_error: 0.0657
# Epoch 40/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0097 - mean_absolute_error: 0.0622 - val_loss: 0.0120 - val_mean_absolute_error: 0.0669
# Epoch 41/50
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0096 - mean_absolute_error: 0.0620 - val_loss: 0.0110 - val_mean_absolute_error: 0.0650
# Epoch 42/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0096 - mean_absolute_error: 0.0621 - val_loss: 0.0116 - val_mean_absolute_error: 0.0644
# Epoch 43/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0095 - mean_absolute_error: 0.0614 - val_loss: 0.0111 - val_mean_absolute_error: 0.0660
# Epoch 44/50
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0095 - mean_absolute_error: 0.0616 - val_loss: 0.0109 - val_mean_absolute_error: 0.0639
# Epoch 45/50
# 383/383 [==============================] - 5s 14ms/step - loss: 0.0094 - mean_absolute_error: 0.0613 - val_loss: 0.0110 - val_mean_absolute_error: 0.0676
# Epoch 46/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0094 - mean_absolute_error: 0.0611 - val_loss: 0.0110 - val_mean_absolute_error: 0.0661
# Epoch 47/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0093 - mean_absolute_error: 0.0610 - val_loss: 0.0108 - val_mean_absolute_error: 0.0650
# Epoch 48/50
# 383/383 [==============================] - 6s 17ms/step - loss: 0.0093 - mean_absolute_error: 0.0608 - val_loss: 0.0108 - val_mean_absolute_error: 0.0645
# Epoch 49/50
# 383/383 [==============================] - 5s 13ms/step - loss: 0.0092 - mean_absolute_error: 0.0604 - val_loss: 0.0108 - val_mean_absolute_error: 0.0650
# Epoch 50/50
# 383/383 [==============================] - 6s 16ms/step - loss: 0.0092 - mean_absolute_error: 0.0604 - val_loss: 0.0109 - val_mean_absolute_error: 0.0642
# 109/109 [==============================] - 1s 8ms/step - loss: 0.0109 - mean_absolute_error: 0.0642

# %%
multi_window.plot(ms_lstm_model)

plt.savefig('figures', dpi=300)

# %%
ms_mae_val = [0.352, 0.347, 0.088, 0.078]
ms_mae_test = [0.347, 0.341, 0.076, 0.064]

# %%
ms_mae_val.append(ms_val_performance['LSTM'][1])
ms_mae_test.append(ms_performance['LSTM'][1])

x = np.arange(5)

labels = ['Baseline - Last', 'Baseline - Repeat', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, ms_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, ms_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(ms_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

for index, value in enumerate(ms_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.4)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# + **Figura 15.12 El MAE de todos los modelos de múltiples pasos construidos hasta ahora. Nuevamente, el LSTM es el modelo ganador, ya que logra el MAE más bajo tanto en el conjunto de validación como en el de prueba.**

# %% [markdown]
# # **15.3.3. Implementación de un LSTM como un modelo de múltiples salidas**
# ### **Paso 34. Implementación de un LSTM como un modelo de múltiples salidas**
# + Por último, implementaremos un LSTM como un modelo de múltiples salidas.
# + Nuevamente, utilizaremos 24 horas de datos de entrada, de modo que la red pueda procesar una secuencia de puntos de datos y utilizar información anterior para generar pronósticos.
# + Los pronósticos serán tanto para el volumen de tráfico como para la temperatura en el siguiente intervalo de tiempo.
#
# + En esta situación, la ventana de datos consta de una entrada de 24 intervalos de tiempo y 24 intervalos de tiempo de etiquetas.
# + El cambio es 1, ya que queremos generar pronósticos solo para el siguiente intervalo de tiempo.
# + Por lo tanto, nuestro modelo creará pronósticos continuos para generar predicciones un intervalo de tiempo a la vez, a lo largo de 24 intervalos de tiempo.
# + Especificaremos `temp` y `Traffic_volume` como nuestras columnas de destino.
# + El siguiente paso es definir nuestro modelo LSTM.
# + Al igual que antes, utilizaremos el modelo secuencial para apilar una capa LSTM y una capa de salida densa con dos unidades, ya que tenemos dos objetivos.
# + Luego entrenaremos el modelo y almacenaremos sus métricas de rendimiento para comparar.
# + Ahora podemos visualizar la predicción del volumen de tráfico (figura 15.13) y la temperatura (figura 15.14).
# + Ambas figuras muestran muchas predicciones (mostradas como cruces) que se superponen a las etiquetas (mostradas como cuadrados), lo que significa que tenemos un modelo de alto rendimiento que genera predicciones precisas.
# + Tenemos dos unidades porque tenemos dos objetivos: la temperatura y
# el volumen de tráfico.
# + Comparemos el rendimiento de nuestro modelo LSTM con los otros modelos de múltiples salidas creados hasta ahora.
# + La Figura 15.15 muestra nuevamente que el LSTM es el modelo ganador, ya que logra el MAE más bajo en los conjuntos de validación y prueba.
# + Por lo tanto, generó las predicciones más precisas hasta el momento para ambos objetivos.

# %%
mo_single_step_window = DataWindow(input_width=1, label_width=1, shift=1, label_columns=['temp','traffic_volume'])
mo_wide_window = DataWindow(input_width=24, label_width=24, shift=1, label_columns=['temp','traffic_volume'])

# %%
# Valores del capítulo 14

mo_mae_val = [0.048, 0.039, 0.023]
mo_mae_test = [0.047, 0.036, 0.020]

# %%
mo_lstm_model = Sequential([
    LSTM(32, return_sequences=True),
    Dense(units = 2)
])

history = compile_and_fit(mo_lstm_model, mo_wide_window)

mo_val_performance = {}
mo_performance = {}

mo_val_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.val)
mo_performance['LSTM'] = mo_lstm_model.evaluate(mo_wide_window.test, verbose=0)
# Out:
# Epoch 1/50
# 384/384 [==============================] - 11s 19ms/step - loss: 0.0290 - mean_absolute_error: 0.1126 - val_loss: 0.0113 - val_mean_absolute_error: 0.0683
# Epoch 2/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0073 - mean_absolute_error: 0.0546 - val_loss: 0.0051 - val_mean_absolute_error: 0.0450
# Epoch 3/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0042 - mean_absolute_error: 0.0407 - val_loss: 0.0033 - val_mean_absolute_error: 0.0368
# Epoch 4/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0032 - mean_absolute_error: 0.0352 - val_loss: 0.0026 - val_mean_absolute_error: 0.0324
# Epoch 5/50
# 384/384 [==============================] - 6s 17ms/step - loss: 0.0027 - mean_absolute_error: 0.0324 - val_loss: 0.0022 - val_mean_absolute_error: 0.0303
# Epoch 6/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0024 - mean_absolute_error: 0.0304 - val_loss: 0.0020 - val_mean_absolute_error: 0.0288
# Epoch 7/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0022 - mean_absolute_error: 0.0291 - val_loss: 0.0019 - val_mean_absolute_error: 0.0278
# Epoch 8/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0021 - mean_absolute_error: 0.0278 - val_loss: 0.0017 - val_mean_absolute_error: 0.0264
# Epoch 9/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0019 - mean_absolute_error: 0.0268 - val_loss: 0.0016 - val_mean_absolute_error: 0.0265
# Epoch 10/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0018 - mean_absolute_error: 0.0259 - val_loss: 0.0015 - val_mean_absolute_error: 0.0247
# Epoch 11/50
# 384/384 [==============================] - 6s 17ms/step - loss: 0.0017 - mean_absolute_error: 0.0252 - val_loss: 0.0014 - val_mean_absolute_error: 0.0244
# Epoch 12/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0017 - mean_absolute_error: 0.0246 - val_loss: 0.0014 - val_mean_absolute_error: 0.0233
# Epoch 13/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.0013 - val_mean_absolute_error: 0.0233
# Epoch 14/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0016 - mean_absolute_error: 0.0237 - val_loss: 0.0013 - val_mean_absolute_error: 0.0222
# Epoch 15/50
# 384/384 [==============================] - 6s 17ms/step - loss: 0.0015 - mean_absolute_error: 0.0233 - val_loss: 0.0013 - val_mean_absolute_error: 0.0230
# Epoch 16/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0230 - val_loss: 0.0012 - val_mean_absolute_error: 0.0225
# Epoch 17/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0227 - val_loss: 0.0012 - val_mean_absolute_error: 0.0220
# Epoch 18/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0015 - mean_absolute_error: 0.0225 - val_loss: 0.0012 - val_mean_absolute_error: 0.0218
# Epoch 19/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0223 - val_loss: 0.0013 - val_mean_absolute_error: 0.0245
# Epoch 20/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0221 - val_loss: 0.0011 - val_mean_absolute_error: 0.0206
# Epoch 21/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0208
# Epoch 22/50
# 384/384 [==============================] - 5s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0217 - val_loss: 0.0011 - val_mean_absolute_error: 0.0209
# Epoch 23/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0216 - val_loss: 0.0011 - val_mean_absolute_error: 0.0211
# Epoch 24/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0014 - mean_absolute_error: 0.0215 - val_loss: 0.0010 - val_mean_absolute_error: 0.0202
# Epoch 25/50
# 384/384 [==============================] - 6s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 0.0011 - val_mean_absolute_error: 0.0202
# Epoch 26/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 0.0010 - val_mean_absolute_error: 0.0198
# Epoch 27/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 0.0010 - val_mean_absolute_error: 0.0207
# Epoch 28/50
# 384/384 [==============================] - 6s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0210 - val_loss: 0.0010 - val_mean_absolute_error: 0.0200
# Epoch 29/50
# 384/384 [==============================] - 7s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0210 - val_loss: 9.9288e-04 - val_mean_absolute_error: 0.0195
# Epoch 30/50
# 384/384 [==============================] - 6s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0207 - val_loss: 0.0010 - val_mean_absolute_error: 0.0205
# Epoch 31/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0207 - val_loss: 9.7373e-04 - val_mean_absolute_error: 0.0197
# Epoch 32/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0206 - val_loss: 9.8443e-04 - val_mean_absolute_error: 0.0197
# Epoch 33/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 9.7752e-04 - val_mean_absolute_error: 0.0197
# Epoch 34/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0206 - val_loss: 9.5218e-04 - val_mean_absolute_error: 0.0191
# Epoch 35/50
# 384/384 [==============================] - 6s 17ms/step - loss: 0.0012 - mean_absolute_error: 0.0204 - val_loss: 9.1597e-04 - val_mean_absolute_error: 0.0186
# Epoch 36/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 9.4093e-04 - val_mean_absolute_error: 0.0190
# Epoch 37/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 9.1889e-04 - val_mean_absolute_error: 0.0189
# Epoch 38/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0202 - val_loss: 8.9028e-04 - val_mean_absolute_error: 0.0184
# Epoch 39/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0201 - val_loss: 8.9960e-04 - val_mean_absolute_error: 0.0184
# Epoch 40/50
# 384/384 [==============================] - 5s 13ms/step - loss: 0.0012 - mean_absolute_error: 0.0200 - val_loss: 9.4251e-04 - val_mean_absolute_error: 0.0196
# Epoch 41/50
# 384/384 [==============================] - 6s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0199 - val_loss: 9.1741e-04 - val_mean_absolute_error: 0.0193
# 109/109 [==============================] - 1s 5ms/step - loss: 9.1741e-04 - mean_absolute_error: 0.0193

# %%
mo_wide_window.plot(mo_lstm_model)

plt.savefig('figures', dpi=300)

# %%
mo_wide_window.plot(model=mo_lstm_model, plot_col='temp')

plt.savefig('figures', dpi=300)

# %%
mo_mae_val.append(mo_val_performance['LSTM'][1])
mo_mae_test.append(mo_performance['LSTM'][1])

x = np.arange(4)

labels = ['Baseline - Last', 'Linear', 'Dense', 'LSTM']

fig, ax = plt.subplots()
ax.bar(x - 0.15, mo_mae_val, width=0.25, color='black', edgecolor='black', label='Validation')
ax.bar(x + 0.15, mo_mae_test, width=0.25, color='white', edgecolor='black', hatch='/', label='Test')
ax.set_ylabel('Mean absolute error')
ax.set_xlabel('Models')

for index, value in enumerate(mo_mae_val):
    plt.text(x=index - 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

for index, value in enumerate(mo_mae_test):
    plt.text(x=index + 0.15, y=value+0.0025, s=str(round(value, 3)), ha='center')

plt.ylim(0, 0.06)
plt.xticks(ticks=x, labels=labels)
plt.legend(loc='best')
plt.tight_layout()

plt.savefig('figures', dpi=300)

# %% [markdown]
# # **14.3. Próximos pasos**
# + En este capítulo, examinamos la arquitectura de la memoria a corto plazo (LSTM).
# + Aprendiste que es un subtipo de RNN y viste cómo utiliza un estado de celda para superar el problema de la memoria a corto plazo que ocurre en una RNN básica que utiliza solo el estado oculto.
# + También estudiamos las tres puertas de la LSTM.
# + La puerta de olvido determina qué información del pasado y del presente debe conservarse, la puerta de entrada determina la información relevante del elemento actual de una secuencia y la puerta de salida utiliza la información almacenada en la memoria para generar una predicción.
# + Luego implementamos la LSTM como un modelo de un solo paso, un modelo de varios pasos y un modelo de múltiples salidas.
# + En todos los casos, la LSTM fue el modelo ganador, ya que logró el MAE más bajo de todos los modelos construidos hasta ahora.

# %% [markdown]
# # **Resumen**
# + Una red neuronal recurrente (RNN) es una arquitectura de aprendizaje profundo especialmente adaptada al procesamiento de secuencias de datos como una serie temporal.
# + Las RNN utilizan un estado oculto para almacenar información en la memoria.
# + Sin embargo, esta es solo una memoria de corto plazo debido al problema del gradiente de desaparición.
# + La memoria de corto plazo larga (LSTM) es un tipo de RNN que aborda el problema de la memoria de corto plazo.
# + Utiliza un estado de celda para almacenar información durante un tiempo más largo, lo que le da a la red una memoria larga.
# + La LSTM está formada por tres puertas:
#   + La puerta de olvido determina qué información del pasado y del presente debe conservarse.
#   + La puerta de entrada determina qué información del presente debe conservarse.
#   + La puerta de salida utiliza la información almacenada en la memoria para procesar el elemento actual de una secuencia
